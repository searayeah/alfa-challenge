# %%
import gc
import os
import pickle

import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import StratifiedKFold
from tqdm.notebook import tqdm
from tsfresh import extract_features, extract_relevant_features
from tsfresh.feature_extraction.settings import EfficientFCParameters
from tsfresh.utilities.dataframe_functions import impute

DATA_FEATURES_FOLDER = "data/features"
TIME_PERIOD_MAPPING = {"M": "month", "W": "week", "D": "day"}

# %%
def reduce_df_size(
    df: pd.DataFrame, force_cat: list | None = None, drop: list | None = None
) -> pd.DataFrame:

    start_mem = df.memory_usage().sum() / 1024**2
    print(f"Memory usage of dataframe is {start_mem:.2f} MB")

    # drops
    if drop:
        for drop_col in drop:
            df = df.drop(drop_col, axis=1)

    float_columns = df.select_dtypes("float").columns
    integer_columns = df.select_dtypes("integer").columns

    # for float all are possible from float to unsigned
    df[float_columns] = df[float_columns].apply(pd.to_numeric, downcast="float")
    df[float_columns] = df[float_columns].apply(pd.to_numeric, downcast="integer")
    df[float_columns] = df[float_columns].apply(pd.to_numeric, downcast="unsigned")

    # for integer two possibilities
    df[integer_columns] = df[integer_columns].apply(pd.to_numeric, downcast="integer")
    df[integer_columns] = df[integer_columns].apply(pd.to_numeric, downcast="unsigned")

    # category
    if force_cat:
        for category_col in force_cat:
            df[category_col] = df[category_col].astype("category")

    end_mem = df.memory_usage().sum() / 1024**2
    print(f"Memory usage after optimization is: {end_mem:.2f} MB")
    print(f"Decreased by {100 * (start_mem - end_mem) / start_mem:.1f}%")
    return df


def cache_or_generate(filename, generator_function, load, *args, **kwargs):
    if load:
        if os.path.exists(filename):
            with open(filename, "rb") as f:
                print(f"Loading data from {filename}")
                return pickle.load(f)
        else:
            print(f"Generating and saving data to {filename}")
            data = generator_function(*args, **kwargs)
            with open(filename, "wb") as f:
                pickle.dump(data, f)
            return data
    else:
        print("Not loading")
        return None

# %%
df_transactions = pd.read_parquet("data/df_transaction.pa")
df_train = pd.read_parquet("data/train.pa")

df_train = reduce_df_size(df_train)
df_transactions = reduce_df_size(df_transactions, drop=["merchant_name"])


# df_train = df_train[df_train["client_num"] < 500]
# df_transactions = df_transactions[df_transactions["client_num"] < 500]


test_clients = list(
    set(df_transactions["client_num"].unique().tolist()).difference(
        df_train["client_num"].to_list()
    )
)

transactions = {
    "train": df_transactions[~df_transactions["client_num"].isin(test_clients)],
    "test": df_transactions[df_transactions["client_num"].isin(test_clients)],
}
# Out:
# Memory usage of dataframe is 1.07 MB
# Memory usage after optimization is: 0.33 MB
# Decreased by 68.7%
# Memory usage of dataframe is 515.30 MB
# Memory usage after optimization is: 309.18 MB
# Decreased by 40.0%

# %%
LOAD = False
AGGS = ["sum", "std", "mean", "min", "max"]


def generate_amount_ts(df, period):
    return reduce_df_size(
        df.set_index("date_time")
        .groupby("client_num")
        .resample(period)["amount"]
        .agg(AGGS)
        .reset_index()
    )


trans_amt_aggs = {}

for split, dataset in transactions.items():
    trans_amt_aggs[split] = {}
    for short_period, full_period in TIME_PERIOD_MAPPING.items():
        file_path = f"{DATA_FEATURES_FOLDER}/{split}_transactions_{full_period}.pkl"
        trans_amt_aggs[split][full_period] = cache_or_generate(
            file_path, generate_amount_ts, LOAD, dataset, short_period
        )
# Out:
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading

# %%
PARAMS = EfficientFCParameters()
N_JOBS = 16
LOAD = False


def extract_tsfresh_features(df, column_id, column_sort, column_value, y=None):
    df = df.fillna(0)
    result = None
    print("Extracting", column_value, "y=", type(y))
    if y is not None:
        result = extract_relevant_features(
            df,
            y=y,
            column_id=column_id,
            column_sort=column_sort,
            column_value=column_value,
            n_jobs=N_JOBS,
            default_fc_parameters=PARAMS,
        )
    else:
        result = extract_features(
            df,
            column_id=column_id,
            column_sort=column_sort,
            column_value=column_value,
            n_jobs=N_JOBS,
            default_fc_parameters=PARAMS,
            impute_function=impute,
        )
    print("Extracting", column_value, "shape=", result.shape)

    return result


def extract_tsfresh_features_ts_columns(df, column_id, column_sort, ts_columns, y=None):
    results = []
    for col in ts_columns:
        result = extract_tsfresh_features(df, column_id, column_sort, col, y)
        results.append(result)
    concat_df = pd.concat(results, axis=1)
    print("Concat shape", concat_df.shape)
    return concat_df


column_id = "client_num"
column_sort = "date_time"
y = df_train.set_index("client_num").iloc[:, 0]  # series required
column_value = "amount"

trans_amt_aggs_features = {}

# aggs
for split, aggs_datasets in trans_amt_aggs.items():
    trans_amt_aggs_features[split] = {}
    for full_period, dataset in aggs_datasets.items():
        file_path = (
            f"{DATA_FEATURES_FOLDER}/{split}_transactions_{full_period}_features.pkl"
        )
        trans_amt_aggs_features[split][full_period] = cache_or_generate(
            file_path,
            extract_tsfresh_features_ts_columns,
            LOAD,
            df=dataset,
            column_id=column_id,
            column_sort=column_sort,
            ts_columns=AGGS,
            y=y if split == "train" else None,
        )

# full
for split, dataset in transactions.items():
    file_path = f"{DATA_FEATURES_FOLDER}/{split}_transactions_full_features.pkl"

    trans_amt_aggs_features[split]["full"] = cache_or_generate(
        file_path,
        extract_tsfresh_features,
        LOAD,
        df=dataset,
        column_id=column_id,
        column_sort=column_sort,
        column_value=column_value,
        y=y if split == "train" else None,
    )
# Out:
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading
# Not loading

# %%
LOAD = True


def create_amount_ts_features(split_period_df_dict):
    for period, dataset in split_period_df_dict.items():
        split_period_df_dict[period] = dataset.add_prefix(f"ts_{period}_")

    amount_ts_features = pd.concat(list(split_period_df_dict.values()), axis=1)

    print("Shape before", amount_ts_features.shape)
    amount_ts_features = amount_ts_features.T.drop_duplicates().T
    amount_ts_features = amount_ts_features.loc[:, amount_ts_features.nunique() > 1]
    amount_ts_features = reduce_df_size(amount_ts_features)
    print("Shape after", amount_ts_features.shape)

    return amount_ts_features


ts_features = {}

for split, datasets_features in trans_amt_aggs_features.items():
    file_path = f"{DATA_FEATURES_FOLDER}/{split}_amount_ts_features.pkl"
    ts_features[split] = cache_or_generate(
        file_path,
        create_amount_ts_features,
        LOAD,
        split_period_df_dict=datasets_features,
    )
# Out:
# Loading data from data/features/train_amount_ts_features.pkl
# Loading data from data/features/test_amount_ts_features.pkl

# %%
train_features = ts_features["train"]
test_features = ts_features["test"]

common_columns = train_features.columns.intersection(test_features.columns)
train_features = train_features[common_columns]
test_features = test_features[common_columns]

print(train_features.shape)
print(test_features.shape)
# Out:
# (70000, 4505)
# (39143, 4505)

# %%
train_features = train_features.reset_index()
train_features = train_features.rename(columns={"index": "client_num"})
test_features = test_features.reset_index()
test_features = test_features.rename(columns={"index": "client_num"})

# %%
tsfresh_features = pd.concat([train_features, test_features])
tsfresh_features
# Out:
#        client_num  ts_month_sum_sum__sum_values  \
# 0               1                        863878
# 1               2                        344108
# 2               3                       1621825
# 3               4                        199796
# 4               5                         67359
# ...           ...                           ...
# 39138      109127                       1960002
# 39139      109128                         28357
# 39140      109130                          3588
# 39141      109137                          3723
# 39142      109140                         28389
#
#        ts_month_sum_sum__quantile__q_0.3  ts_month_sum_sum__quantile__q_0.4  \
# 0                               223786.2                           230229.6
# 1                               101008.2                           107827.6
# 2                                69126.6                            69467.8
# 3                                56091.6                            59900.8
# 4                                18945.8                            19078.4
# ...                                  ...                                ...
# 39138                           162000.0                           216000.0
# 39139                            28357.0                            28357.0
# 39140                              767.2                              852.6
# 39141                             3723.0                             3723.0
# 39142                             8664.3                            11429.4
#
#        ts_month_sum_sum__quantile__q_0.6  ts_month_sum_sum__quantile__q_0.7  \
# 0                               273888.2                           311103.4
# 1                               121499.8                           128352.6
# 2                               352629.8                           635450.6
# 3                                69252.4                            74794.8
# 4                                21288.8                            23366.6
# ...                                  ...                                ...
# 39138                           554000.4                           838000.8
# 39139                            28357.0                            28357.0
# 39140                             1178.2                             1418.4
# 39141                             3723.0                             3723.0
# 39142                            16959.6                            19724.7
#
#        ts_month_sum_sum__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)  \
# 0                                           3.553388e+05
# 1                                           1.030089e+05
# 2                                           9.377156e+05
# 3                                           8.192955e+04
# 4                                           2.568245e+04
# ...                                                  ...
# 39138                                       1.036464e+06
# 39139                                       1.739111e+04
# 39140                                       7.826929e+02
# 39141                                       2.283284e+03
# 39142                                       2.056330e+02
#
#        ts_month_sum_sum__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)  \
# 0                                          250359.229482
# 1                                           73869.259141
# 2                                          600436.513367
# 3                                           58714.306632
# 4                                           18251.089477
# ...                                                  ...
# 39138                                      655517.237708
# 39139                                       10999.100776
# 39140                                         550.341468
# 39141                                        1444.075614
# 39142                                         140.989570
#
#        ts_month_sum_sum__quantile__q_0.1  \
# 0                               210899.4
# 1                                87369.4
# 2                                68444.2
# 3                                48473.2
# 4                                18680.6
# ...                                  ...
# 39138                            54000.0
# 39139                            28357.0
# 39140                              596.4
# 39141                             3723.0
# 39142                             3134.1
#
#        ts_month_sum_sum__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)  \
# 0                                          179891.523475
# 1                                           53207.112289
# 2                                          425395.933829
# 3                                           42287.386989
# 4                                           13129.670410
# ...                                                  ...
# 39138                                      463520.683968
# 39139                                        7777.538746
# 2                                                 1
# 3                                                 1
# 4                                                 1
# ...                                             ...
# 39138                                             1
# 39139                                             1
# 39140                                             1
# 39141                                             1
# 39142                                             1
#
#        ts_full_FULL_amount__cwt_coefficients__coeff_10__w_2__widths_(2, 5, 10, 20)
# 0                                           36436.719427
# 1                                            -725.189242
# 2                                         -152611.379219
# 3                                            8848.187406
# 4                                            -178.094475
# ...                                                  ...
# 39138                                     -244150.505170
# 39139                                        -407.724002
# 39140                                          80.453643
# 39141                                          52.914136
# 39142                                        -438.480296
#
# [109143 rows x 4506 columns]

# %%
assert tsfresh_features.isna().sum().sum() == 0

# %%
tsfresh_features.to_pickle("data/features/tsfresh_generations.pkl")

# %%
df_train
# Out:
#        client_num  target
# 0           94779       3
# 1           17279       0
# 2            5717       2
# 3           27471       1
# 4           72725       0
# ...           ...     ...
# 69995      107219       1
# 69996      108682       1
# 69997       93497       3
# 69998       14344       6
# 69999       83262       1
#
# [70000 rows x 2 columns]

# %%
df_train = df_train.merge(
    train_features, left_on="client_num", right_on="index", how="left"
)

del train_features
gc.collect()
# Out:
# 0

# %%
X_train = df_train.drop(["target", "client_num", "index"], axis=1)
y_train = df_train["target"]

test_features = test_features.reset_index()
test_features = test_features.rename(columns={"index": "client_num"})

submission = test_features[["client_num"]]
X_test = test_features.drop("client_num", axis=1)

# %%
test_features
# Out:
#        client_num  ts_month_sum_sum__sum_values  \
# 0               0                        106935
# 1              10                       3020981
# 2              11                        200840
# 3              14                        711788
# 4              16                        117194
# ...           ...                           ...
# 39138      109127                       1960002
# 39139      109128                         28357
# 39140      109130                          3588
# 39141      109137                          3723
# 39142      109140                         28389
#
#        ts_month_sum_sum__quantile__q_0.3  ts_month_sum_sum__quantile__q_0.4  \
# 0                                28531.6                            35621.8
# 1                               696874.6                           737464.8
# 2                                55898.4                            61389.2
# 3                               225890.2                           227823.6
# 4                                35142.8                            44218.4
# ...                                  ...                                ...
# 39138                           162000.0                           216000.0
# 39139                            28357.0                            28357.0
# 39140                              767.2                              852.6
# 39141                             3723.0                             3723.0
# 39142                             8664.3                            11429.4
#
#        ts_month_sum_sum__quantile__q_0.6  ts_month_sum_sum__quantile__q_0.7  \
# 0                                45562.0                            48412.0
# 1                               956008.4                          1133961.8
# 2                                72410.8                            77941.6
# 3                               236193.8                           242630.6
# 4                                53832.0                            54370.0
# ...                                  ...                                ...
# 39138                           554000.4                           838000.8
# 39139                            28357.0                            28357.0
# 39140                             1178.2                             1418.4
# 39141                             3723.0                             3723.0
# 39142                            16959.6                            19724.7
#
#        ts_month_sum_sum__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)  \
# 0                                           2.757517e+04
# 1                                           1.338690e+06
# 2                                           7.939025e+04
# 3                                           2.539093e+05
# 4                                           5.540983e+04
# ...                                                  ...
# 39138                                       1.036464e+06
# 39139                                       1.739111e+04
# 39140                                       7.826929e+02
# 39141                                       2.283284e+03
# 39142                                       2.056330e+02
#
#        ts_month_sum_sum__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)  \
#        ts_full_FULL_amount__autocorrelation__lag_1  \
# 0                                         0.237970
# 1                                         0.113700
# 2                                         0.110089
# 3                                         0.013820
# 4                                         0.142226
# ...                                            ...
# 39138                                     0.479598
# 39139                                     0.105864
# 39140                                    -0.274564
# 39141                                    -0.146298
# 39142                                     0.478676
#
#        ts_full_FULL_amount__fft_coefficient__attr_"real"__coeff_16  \
# 0                                            4691.062603
# 1                                          401290.399130
# 2                                          -21748.131402
# 3                                         -108314.718056
# 4                                            1703.497581
# ...                                                  ...
# 39138                                         236.363474
# 39139                                         236.363474
# 39140                                         236.363474
# 39141                                         236.363474
# 39142                                         236.363474
#
#        ts_full_FULL_amount__symmetry_looking__r_0.2  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
# ...                                             ...
# 39138                                             1
# 39139                                             1
# 39140                                             1
# 39141                                             1
# 39142                                             1
#
#        ts_full_FULL_amount__cwt_coefficients__coeff_10__w_2__widths_(2, 5, 10, 20)
# 0                                              -3.342568
# 1                                            1157.217300
# 2                                             -38.124623
# 3                                            2566.103837
# 4                                            -171.209523
# ...                                                  ...
# 39138                                     -244150.505170
# 39139                                        -407.724002
# 39140                                          80.453643
# 39141                                          52.914136
# 39142                                        -438.480296
#
# [39143 rows x 4506 columns]

# %%
assert X_train.shape[0] == 70000
assert X_test.shape[0] == 39143
assert df_train.isna().sum().sum() == 0
assert X_test.isna().sum().sum() == 0

# %%
CAT_FEATURES = X_train.select_dtypes("object").columns.to_list()
EARLY_STOPPING = 400
EVAL_METRIC = "MAE"

models_list = []
scores_list = []

splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for i, (train_index, test_index) in tqdm(enumerate(splitter.split(X_train, y_train))):
    X_fold_train, y_fold_train = X_train.iloc[train_index], y_train.iloc[train_index]
    X_fold_test, y_fold_test = X_train.iloc[test_index], y_train.iloc[test_index]

    model = CatBoostRegressor(
        iterations=10000,
        loss_function="MAE",
        cat_features=CAT_FEATURES,
        learning_rate=0.03,
        depth=4,
        # verbose=0,
        eval_metric=EVAL_METRIC,
        early_stopping_rounds=EARLY_STOPPING,
        task_type="GPU",
        # depth=4,
    )

    model.fit(X_fold_train, y_fold_train, eval_set=(X_fold_test, y_fold_test))
    preds = model.predict(X_fold_test)

    score = mean_absolute_error(y_fold_test, preds)

    models_list.append(model)
    scores_list.append(score)

print(np.mean(scores_list), np.std(scores_list))
# Out:
# 0it [00:00, ?it/s]
# Default metric period is 5 because MAE is/are not implemented for GPU
# 0:	learn: 1.5803788	test: 1.5801113	best: 1.5801113 (0)	total: 380ms	remaining: 1h 3m 14s
# 1:	total: 415ms	remaining: 34m 34s
# 2:	total: 452ms	remaining: 25m 5s
# 3:	total: 490ms	remaining: 20m 24s
# 4:	total: 522ms	remaining: 17m 23s
# 5:	learn: 1.5732952	test: 1.5729799	best: 1.5729799 (5)	total: 554ms	remaining: 15m 23s
# 6:	total: 585ms	remaining: 13m 55s
# 7:	total: 619ms	remaining: 12m 53s
# 8:	total: 648ms	remaining: 11m 59s
# 9:	total: 678ms	remaining: 11m 16s
# 61:	total: 2.36s	remaining: 6m 18s
# 62:	total: 2.39s	remaining: 6m 17s
# 63:	total: 2.42s	remaining: 6m 16s
# 64:	total: 2.45s	remaining: 6m 14s
# 65:	learn: 1.4915946	test: 1.4906014	best: 1.4906014 (65)	total: 2.48s	remaining: 6m 14s
# 66:	total: 2.52s	remaining: 6m 13s
# 67:	total: 2.55s	remaining: 6m 11s
# 68:	total: 2.58s	remaining: 6m 11s
# 69:	total: 2.61s	remaining: 6m 10s
# 70:	learn: 1.4850582	test: 1.4839973	best: 1.4839973 (70)	total: 2.64s	remaining: 6m 9s
# 71:	total: 2.67s	remaining: 6m 8s
# 72:	total: 2.7s	remaining: 6m 7s
# 73:	total: 2.73s	remaining: 6m 6s
# 74:	total: 2.77s	remaining: 6m 5s
# 75:	learn: 1.4783135	test: 1.4771994	best: 1.4771994 (75)	total: 2.8s	remaining: 6m 5s
# 76:	total: 2.83s	remaining: 6m 5s
# 77:	total: 2.86s	remaining: 6m 4s
# 78:	total: 2.89s	remaining: 6m 3s
# 79:	total: 2.92s	remaining: 6m 2s
# 80:	learn: 1.4713338	test: 1.4701928	best: 1.4701928 (80)	total: 2.95s	remaining: 6m 1s
# 81:	total: 2.99s	remaining: 6m 1s
# 82:	total: 3.02s	remaining: 6m
# 83:	total: 3.05s	remaining: 6m
# 84:	total: 3.08s	remaining: 5m 59s
# 85:	learn: 1.4645578	test: 1.4633244	best: 1.4633244 (85)	total: 3.11s	remaining: 5m 58s
# 86:	total: 3.14s	remaining: 5m 58s
# 87:	total: 3.18s	remaining: 5m 58s
# 88:	total: 3.21s	remaining: 5m 57s
# 89:	total: 3.24s	remaining: 5m 56s
# 90:	learn: 1.4578161	test: 1.4564794	best: 1.4564794 (90)	total: 3.27s	remaining: 5m 56s
# 91:	total: 3.3s	remaining: 5m 55s
# 92:	total: 3.34s	remaining: 5m 55s
# 93:	total: 3.37s	remaining: 5m 55s
# 94:	total: 3.4s	remaining: 5m 54s
# 95:	learn: 1.4509745	test: 1.4495695	best: 1.4495695 (95)	total: 3.44s	remaining: 5m 54s
# 96:	total: 3.47s	remaining: 5m 54s
# 97:	total: 3.51s	remaining: 5m 54s
# 98:	total: 3.54s	remaining: 5m 53s
# 99:	total: 3.57s	remaining: 5m 53s
# 100:	learn: 1.4441769	test: 1.4427220	best: 1.4427220 (100)	total: 3.6s	remaining: 5m 53s
# 101:	total: 3.63s	remaining: 5m 52s
# 102:	total: 3.67s	remaining: 5m 52s
# 103:	total: 3.7s	remaining: 5m 51s
# 104:	total: 3.73s	remaining: 5m 51s
# 105:	learn: 1.4372789	test: 1.4357617	best: 1.4357617 (105)	total: 3.77s	remaining: 5m 51s
# 106:	total: 3.8s	remaining: 5m 51s
# 107:	total: 3.83s	remaining: 5m 50s
# 108:	total: 3.86s	remaining: 5m 50s
# 109:	total: 3.9s	remaining: 5m 50s
# 110:	learn: 1.4304321	test: 1.4288689	best: 1.4288689 (110)	total: 3.92s	remaining: 5m 49s
# 111:	total: 3.96s	remaining: 5m 49s
# 112:	total: 3.99s	remaining: 5m 48s
# 113:	total: 4.02s	remaining: 5m 48s
# 114:	total: 4.05s	remaining: 5m 47s
# 115:	learn: 1.4235582	test: 1.4219095	best: 1.4219095 (115)	total: 4.08s	remaining: 5m 47s
# 116:	total: 4.11s	remaining: 5m 47s
# 117:	total: 4.14s	remaining: 5m 47s
# 118:	total: 4.18s	remaining: 5m 46s
# 119:	total: 4.21s	remaining: 5m 46s
# 120:	learn: 1.4168039	test: 1.4150575	best: 1.4150575 (120)	total: 4.24s	remaining: 5m 46s
# 121:	total: 4.27s	remaining: 5m 45s
# 122:	total: 4.3s	remaining: 5m 45s
# 123:	total: 4.33s	remaining: 5m 45s
# 124:	total: 4.37s	remaining: 5m 44s
# 125:	learn: 1.4101857	test: 1.4083587	best: 1.4083587 (125)	total: 4.39s	remaining: 5m 44s
# 126:	total: 4.43s	remaining: 5m 44s
# 127:	total: 4.46s	remaining: 5m 44s
# 128:	total: 4.5s	remaining: 5m 44s
# 129:	total: 4.53s	remaining: 5m 43s
# 130:	learn: 1.4038112	test: 1.4019195	best: 1.4019195 (130)	total: 4.56s	remaining: 5m 43s
# 131:	total: 4.59s	remaining: 5m 43s
# 132:	total: 4.62s	remaining: 5m 42s
# 133:	total: 4.65s	remaining: 5m 42s
# 134:	total: 4.68s	remaining: 5m 41s
# 135:	learn: 1.3976257	test: 1.3956888	best: 1.3956888 (135)	total: 4.71s	remaining: 5m 41s
# 136:	total: 4.74s	remaining: 5m 41s
# 137:	total: 4.77s	remaining: 5m 41s
# 138:	total: 4.81s	remaining: 5m 41s
# 139:	total: 4.84s	remaining: 5m 40s
# 140:	learn: 1.3915718	test: 1.3895668	best: 1.3895668 (140)	total: 4.88s	remaining: 5m 40s
# 141:	total: 4.91s	remaining: 5m 40s
# 142:	total: 4.94s	remaining: 5m 40s
# 143:	total: 4.97s	remaining: 5m 40s
# 144:	total: 5s	remaining: 5m 39s
# 145:	learn: 1.3857093	test: 1.3836254	best: 1.3836254 (145)	total: 5.03s	remaining: 5m 39s
# 146:	total: 5.06s	remaining: 5m 39s
# 147:	total: 5.09s	remaining: 5m 39s
# 148:	total: 5.13s	remaining: 5m 38s
# 149:	total: 5.16s	remaining: 5m 38s
# 150:	learn: 1.3798732	test: 1.3777903	best: 1.3777903 (150)	total: 5.19s	remaining: 5m 38s
# 151:	total: 5.22s	remaining: 5m 38s
# 152:	total: 5.25s	remaining: 5m 38s
# 153:	total: 5.29s	remaining: 5m 38s
# 154:	total: 5.32s	remaining: 5m 37s
# 155:	learn: 1.3741042	test: 1.3720222	best: 1.3720222 (155)	total: 5.35s	remaining: 5m 37s
# 156:	total: 5.38s	remaining: 5m 37s
# 157:	total: 5.42s	remaining: 5m 37s
# 158:	total: 5.45s	remaining: 5m 37s
# 159:	total: 5.48s	remaining: 5m 36s
# 160:	learn: 1.3693059	test: 1.3671274	best: 1.3671274 (160)	total: 5.51s	remaining: 5m 36s
# 161:	total: 5.54s	remaining: 5m 36s
# 162:	total: 5.57s	remaining: 5m 36s
# 163:	total: 5.61s	remaining: 5m 36s
# 164:	total: 5.64s	remaining: 5m 36s
# 165:	learn: 1.3654568	test: 1.3631793	best: 1.3631793 (165)	total: 5.67s	remaining: 5m 35s
# 166:	total: 5.7s	remaining: 5m 35s
# 167:	total: 5.74s	remaining: 5m 35s
# 168:	total: 5.77s	remaining: 5m 35s
# 169:	total: 5.8s	remaining: 5m 35s
# 170:	learn: 1.3621069	test: 1.3598350	best: 1.3598350 (170)	total: 5.83s	remaining: 5m 35s
# 171:	total: 5.86s	remaining: 5m 34s
# 172:	total: 5.89s	remaining: 5m 34s
# 173:	total: 5.92s	remaining: 5m 34s
# 174:	total: 5.95s	remaining: 5m 34s
# 175:	learn: 1.3590706	test: 1.3567281	best: 1.3567281 (175)	total: 5.98s	remaining: 5m 33s
# 176:	total: 6.01s	remaining: 5m 33s
# 177:	total: 6.04s	remaining: 5m 33s
# 178:	total: 6.07s	remaining: 5m 33s
# 179:	total: 6.1s	remaining: 5m 32s
# 180:	learn: 1.3561551	test: 1.3537730	best: 1.3537730 (180)	total: 6.13s	remaining: 5m 32s
# 181:	total: 6.16s	remaining: 5m 32s
# 182:	total: 6.2s	remaining: 5m 32s
# 183:	total: 6.22s	remaining: 5m 32s
# 184:	total: 6.25s	remaining: 5m 31s
# 185:	learn: 1.3533511	test: 1.3510085	best: 1.3510085 (185)	total: 6.28s	remaining: 5m 31s
# 186:	total: 6.31s	remaining: 5m 31s
# 187:	total: 6.34s	remaining: 5m 31s
# 188:	total: 6.38s	remaining: 5m 31s
# 189:	total: 6.41s	remaining: 5m 30s
# 190:	learn: 1.3507889	test: 1.3484517	best: 1.3484517 (190)	total: 6.44s	remaining: 5m 30s
# 191:	total: 6.46s	remaining: 5m 30s
# 192:	total: 6.5s	remaining: 5m 30s
# 193:	total: 6.53s	remaining: 5m 29s
# 194:	total: 6.55s	remaining: 5m 29s
# 195:	learn: 1.3483629	test: 1.3460917	best: 1.3460917 (195)	total: 6.59s	remaining: 5m 29s
# 196:	total: 6.62s	remaining: 5m 29s
# 197:	total: 6.65s	remaining: 5m 29s
# 198:	total: 6.68s	remaining: 5m 28s
# 199:	total: 6.71s	remaining: 5m 28s
# 200:	learn: 1.3460388	test: 1.3437917	best: 1.3437917 (200)	total: 6.74s	remaining: 5m 28s
# 201:	total: 6.77s	remaining: 5m 28s
# 202:	total: 6.8s	remaining: 5m 28s
# 203:	total: 6.83s	remaining: 5m 28s
# 204:	total: 6.86s	remaining: 5m 27s
# 205:	learn: 1.3437358	test: 1.3415311	best: 1.3415311 (205)	total: 6.89s	remaining: 5m 27s
# 206:	total: 6.92s	remaining: 5m 27s
# 207:	total: 6.95s	remaining: 5m 27s
# 208:	total: 6.98s	remaining: 5m 27s
# 209:	total: 7.01s	remaining: 5m 27s
# 210:	learn: 1.3417102	test: 1.3394711	best: 1.3394711 (210)	total: 7.04s	remaining: 5m 26s
# 211:	total: 7.08s	remaining: 5m 26s
# 212:	total: 7.11s	remaining: 5m 26s
# 213:	total: 7.13s	remaining: 5m 26s
# 214:	total: 7.17s	remaining: 5m 26s
# 215:	learn: 1.3396511	test: 1.3374901	best: 1.3374901 (215)	total: 7.2s	remaining: 5m 25s
# 216:	total: 7.23s	remaining: 5m 25s
# 217:	total: 7.26s	remaining: 5m 25s
# 218:	total: 7.26s	remaining: 5m 25s
# 219:	total: 7.28s	remaining: 5m 25s
# 220:	learn: 1.3376730	test: 1.3355826	best: 1.3355826 (220)	total: 7.31s	remaining: 5m 25s
# 221:	total: 7.34s	remaining: 5m 24s
# 222:	total: 7.37s	remaining: 5m 24s
# 223:	total: 7.4s	remaining: 5m 24s
# 224:	total: 7.43s	remaining: 5m 24s
# 225:	learn: 1.3357238	test: 1.3337006	best: 1.3337006 (225)	total: 7.46s	remaining: 5m 24s
# 226:	total: 7.49s	remaining: 5m 23s
# 227:	total: 10.1s	remaining: 7m 16s
# 228:	total: 10.2s	remaining: 7m 15s
# 229:	total: 10.2s	remaining: 7m 15s
# 230:	learn: 1.3339685	test: 1.3320144	best: 1.3320144 (230)	total: 10.2s	remaining: 7m 14s
# 231:	total: 10.2s	remaining: 7m 14s
# 232:	total: 10.3s	remaining: 7m 13s
# 233:	total: 10.3s	remaining: 7m 12s
# 234:	total: 10.3s	remaining: 7m 12s
# 235:	learn: 1.3320731	test: 1.3301357	best: 1.3301357 (235)	total: 10.3s	remaining: 7m 11s
# 236:	total: 10.4s	remaining: 7m 10s
# 237:	total: 10.4s	remaining: 7m 10s
# 238:	total: 13s	remaining: 8m 57s
# 239:	total: 13s	remaining: 8m 57s
# 240:	learn: 1.3304132	test: 1.3285163	best: 1.3285163 (240)	total: 13.1s	remaining: 8m 56s
# 241:	total: 15.7s	remaining: 10m 41s
# 242:	total: 15.7s	remaining: 10m 39s
# 243:	total: 15.8s	remaining: 10m 38s
# 244:	total: 15.8s	remaining: 10m 36s
# 245:	learn: 1.3288394	test: 1.3269132	best: 1.3269132 (245)	total: 15.8s	remaining: 10m 35s
# 246:	total: 15.9s	remaining: 10m 33s
# 247:	total: 15.9s	remaining: 10m 32s
# 248:	total: 15.9s	remaining: 10m 31s
# 249:	total: 15.9s	remaining: 10m 29s
# 250:	learn: 1.3272522	test: 1.3253638	best: 1.3253638 (250)	total: 16s	remaining: 10m 28s
# 251:	total: 16s	remaining: 10m 26s
# 252:	total: 16s	remaining: 10m 25s
# 253:	total: 16.1s	remaining: 10m 23s
# 254:	total: 16.1s	remaining: 10m 22s
# 255:	learn: 1.3256350	test: 1.3238271	best: 1.3238271 (255)	total: 16.1s	remaining: 10m 21s
# 256:	total: 16.2s	remaining: 10m 19s
# 257:	total: 16.2s	remaining: 10m 18s
# 258:	total: 16.2s	remaining: 10m 17s
# 259:	total: 16.2s	remaining: 10m 15s
# 260:	learn: 1.3241514	test: 1.3223852	best: 1.3223852 (260)	total: 16.3s	remaining: 10m 14s
# 261:	total: 16.3s	remaining: 10m 13s
# 262:	total: 16.3s	remaining: 10m 11s
# 263:	total: 16.4s	remaining: 10m 10s
# 264:	total: 16.4s	remaining: 10m 9s
# 368:	total: 19.6s	remaining: 8m 34s
# 369:	total: 19.6s	remaining: 8m 34s
# 370:	learn: 1.3002507	test: 1.2998460	best: 1.2998460 (370)	total: 19.6s	remaining: 8m 33s
# 371:	total: 19.7s	remaining: 8m 32s
# 372:	total: 19.7s	remaining: 8m 32s
# 373:	total: 19.7s	remaining: 8m 31s
# 374:	total: 19.7s	remaining: 8m 30s
# 375:	learn: 1.2995837	test: 1.2992122	best: 1.2992122 (375)	total: 19.8s	remaining: 8m 30s
# 376:	total: 19.8s	remaining: 8m 29s
# 377:	total: 19.8s	remaining: 8m 28s
# 378:	total: 19.9s	remaining: 8m 28s
# 379:	total: 19.9s	remaining: 8m 27s
# 380:	learn: 1.2988398	test: 1.2985289	best: 1.2985289 (380)	total: 19.9s	remaining: 8m 27s
# 381:	total: 20s	remaining: 8m 26s
# 382:	total: 20s	remaining: 8m 25s
# 383:	total: 20s	remaining: 8m 25s
# 384:	total: 20s	remaining: 8m 24s
# 385:	learn: 1.2980467	test: 1.2978057	best: 1.2978057 (385)	total: 20.1s	remaining: 8m 23s
# 386:	total: 20.1s	remaining: 8m 23s
# 387:	total: 20.1s	remaining: 8m 22s
# 388:	total: 20.2s	remaining: 8m 22s
# 389:	total: 20.2s	remaining: 8m 21s
# 390:	learn: 1.2973369	test: 1.2971454	best: 1.2971454 (390)	total: 20.2s	remaining: 8m 21s
# 391:	total: 20.3s	remaining: 8m 20s
# 392:	total: 20.3s	remaining: 8m 19s
# 393:	total: 20.3s	remaining: 8m 19s
# 394:	total: 20.3s	remaining: 8m 18s
# 395:	learn: 1.2967395	test: 1.2965752	best: 1.2965752 (395)	total: 20.4s	remaining: 8m 17s
# 396:	total: 20.4s	remaining: 8m 17s
# 397:	total: 20.4s	remaining: 8m 16s
# 398:	total: 20.5s	remaining: 8m 16s
# 399:	total: 20.5s	remaining: 8m 15s
# 400:	learn: 1.2960958	test: 1.2959987	best: 1.2959987 (400)	total: 20.5s	remaining: 8m 15s
# 401:	total: 20.6s	remaining: 8m 14s
# 402:	total: 20.6s	remaining: 8m 13s
# 403:	total: 20.6s	remaining: 8m 13s
# 404:	total: 20.6s	remaining: 8m 12s
# 405:	learn: 1.2954816	test: 1.2954547	best: 1.2954547 (405)	total: 20.7s	remaining: 8m 12s
# 406:	total: 20.7s	remaining: 8m 11s
# 407:	total: 20.7s	remaining: 8m 11s
# 408:	total: 20.8s	remaining: 8m 10s
# 409:	total: 20.8s	remaining: 8m 10s
# 410:	learn: 1.2948753	test: 1.2949752	best: 1.2949752 (410)	total: 20.8s	remaining: 8m 9s
# 411:	total: 20.9s	remaining: 8m 8s
# 412:	total: 20.9s	remaining: 8m 8s
# 413:	total: 20.9s	remaining: 8m 7s
# 414:	total: 20.9s	remaining: 8m 7s
# 415:	learn: 1.2942921	test: 1.2944121	best: 1.2944121 (415)	total: 21s	remaining: 8m 6s
# 416:	total: 21s	remaining: 8m 6s
# 417:	total: 21s	remaining: 8m 5s
# 418:	total: 21.1s	remaining: 8m 5s
# 521:	total: 34.2s	remaining: 10m 30s
# 522:	total: 34.3s	remaining: 10m 29s
# 523:	total: 34.3s	remaining: 10m 28s
# 524:	total: 34.3s	remaining: 10m 27s
# 525:	learn: 1.2844616	test: 1.2854506	best: 1.2854506 (525)	total: 34.3s	remaining: 10m 26s
# 526:	total: 34.4s	remaining: 10m 26s
# 527:	total: 34.4s	remaining: 10m 25s
# 528:	total: 34.4s	remaining: 10m 24s
# 529:	total: 34.4s	remaining: 10m 23s
# 530:	learn: 1.2841261	test: 1.2851254	best: 1.2851254 (530)	total: 34.5s	remaining: 10m 22s
# 531:	total: 34.5s	remaining: 10m 22s
# 532:	total: 34.5s	remaining: 10m 21s
# 533:	total: 34.5s	remaining: 10m 20s
# 534:	total: 34.6s	remaining: 10m 19s
# 535:	learn: 1.2837801	test: 1.2848438	best: 1.2848438 (535)	total: 34.6s	remaining: 10m 19s
# 536:	total: 34.6s	remaining: 10m 18s
# 537:	total: 34.7s	remaining: 10m 17s
# 538:	total: 34.7s	remaining: 10m 16s
# 539:	total: 34.7s	remaining: 10m 16s
# 540:	learn: 1.2834477	test: 1.2845610	best: 1.2845610 (540)	total: 34.7s	remaining: 10m 15s
# 541:	total: 34.8s	remaining: 10m 14s
# 542:	total: 34.8s	remaining: 10m 13s
# 543:	total: 34.8s	remaining: 10m 13s
# 544:	total: 34.8s	remaining: 10m 12s
# 545:	learn: 1.2831229	test: 1.2842824	best: 1.2842824 (545)	total: 34.9s	remaining: 10m 11s
# 546:	total: 34.9s	remaining: 10m 10s
# 547:	total: 34.9s	remaining: 10m 10s
# 548:	total: 34.9s	remaining: 10m 9s
# 549:	total: 35s	remaining: 10m 8s
# 550:	learn: 1.2828050	test: 1.2840190	best: 1.2840190 (550)	total: 35s	remaining: 10m 7s
# 551:	total: 35s	remaining: 10m 7s
# 552:	total: 35.1s	remaining: 10m 6s
# 553:	total: 35.1s	remaining: 10m 5s
# 554:	total: 35.1s	remaining: 10m 5s
# 555:	learn: 1.2825220	test: 1.2837706	best: 1.2837706 (555)	total: 35.1s	remaining: 10m 4s
# 556:	total: 35.2s	remaining: 10m 3s
# 557:	total: 35.2s	remaining: 10m 2s
# 558:	total: 35.2s	remaining: 10m 2s
# 559:	total: 35.2s	remaining: 10m 1s
# 560:	learn: 1.2822241	test: 1.2834965	best: 1.2834965 (560)	total: 35.3s	remaining: 10m
# 561:	total: 35.3s	remaining: 10m
# 562:	total: 35.3s	remaining: 9m 59s
# 563:	total: 35.4s	remaining: 9m 58s
# 564:	total: 35.4s	remaining: 9m 58s
# 565:	learn: 1.2819100	test: 1.2832393	best: 1.2832393 (565)	total: 35.4s	remaining: 9m 57s
# 566:	total: 35.4s	remaining: 9m 57s
# 567:	total: 35.5s	remaining: 9m 56s
# 568:	total: 35.5s	remaining: 9m 55s
# 569:	total: 35.5s	remaining: 9m 55s
# 570:	learn: 1.2815823	test: 1.2829989	best: 1.2829989 (570)	total: 35.6s	remaining: 9m 54s
# 571:	total: 35.6s	remaining: 9m 53s
# 777:	total: 46.5s	remaining: 9m 17s
# 778:	total: 46.5s	remaining: 9m 17s
# 779:	total: 46.6s	remaining: 9m 16s
# 780:	learn: 1.2712779	test: 1.2748174	best: 1.2748174 (780)	total: 46.6s	remaining: 9m 16s
# 781:	total: 46.6s	remaining: 9m 15s
# 782:	total: 46.6s	remaining: 9m 15s
# 783:	total: 46.6s	remaining: 9m 15s
# 784:	total: 46.7s	remaining: 9m 14s
# 785:	learn: 1.2710921	test: 1.2746991	best: 1.2746991 (785)	total: 46.7s	remaining: 9m 14s
# 786:	total: 46.7s	remaining: 9m 14s
# 787:	total: 46.8s	remaining: 9m 13s
# 788:	total: 46.8s	remaining: 9m 13s
# 789:	total: 46.8s	remaining: 9m 12s
# 790:	learn: 1.2708969	test: 1.2745684	best: 1.2745684 (790)	total: 46.8s	remaining: 9m 12s
# 791:	total: 46.9s	remaining: 9m 11s
# 792:	total: 46.9s	remaining: 9m 11s
# 793:	total: 46.9s	remaining: 9m 10s
# 794:	total: 46.9s	remaining: 9m 10s
# 795:	learn: 1.2706939	test: 1.2744403	best: 1.2744403 (795)	total: 47s	remaining: 9m 10s
# 796:	total: 49.6s	remaining: 9m 40s
# 797:	total: 49.6s	remaining: 9m 39s
# 798:	total: 49.7s	remaining: 9m 39s
# 799:	total: 49.7s	remaining: 9m 38s
# 800:	learn: 1.2704835	test: 1.2742910	best: 1.2742910 (800)	total: 49.7s	remaining: 9m 38s
# 801:	total: 49.7s	remaining: 9m 37s
# 802:	total: 49.8s	remaining: 9m 37s
# 803:	total: 49.8s	remaining: 9m 36s
# 804:	total: 49.8s	remaining: 9m 36s
# 805:	learn: 1.2702920	test: 1.2741579	best: 1.2741579 (805)	total: 49.9s	remaining: 9m 35s
# 806:	total: 49.9s	remaining: 9m 35s
# 807:	total: 49.9s	remaining: 9m 34s
# 808:	total: 49.9s	remaining: 9m 34s
# 809:	total: 50s	remaining: 9m 33s
# 810:	learn: 1.2701136	test: 1.2740479	best: 1.2740479 (810)	total: 50s	remaining: 9m 33s
# 811:	total: 50s	remaining: 9m 32s
# 812:	total: 50s	remaining: 9m 32s
# 813:	total: 50.1s	remaining: 9m 32s
# 814:	total: 50.1s	remaining: 9m 31s
# 815:	learn: 1.2699501	test: 1.2739422	best: 1.2739422 (815)	total: 50.1s	remaining: 9m 31s
# 816:	total: 50.1s	remaining: 9m 30s
# 817:	total: 50.2s	remaining: 9m 30s
# 818:	total: 50.2s	remaining: 9m 29s
# 819:	total: 50.2s	remaining: 9m 29s
# 820:	learn: 1.2697215	test: 1.2737953	best: 1.2737953 (820)	total: 50.3s	remaining: 9m 28s
# 821:	total: 50.3s	remaining: 9m 28s
# 822:	total: 50.3s	remaining: 9m 27s
# 823:	total: 50.3s	remaining: 9m 27s
# 824:	total: 50.4s	remaining: 9m 27s
# 825:	learn: 1.2695233	test: 1.2736722	best: 1.2736722 (825)	total: 50.4s	remaining: 9m 26s
# 826:	total: 50.4s	remaining: 9m 26s
# 827:	total: 50.4s	remaining: 9m 25s
# 930:	learn: 1.2660446	test: 1.2713984	best: 1.2713984 (930)	total: 58.4s	remaining: 9m 36s
# 931:	total: 58.4s	remaining: 9m 36s
# 932:	total: 58.5s	remaining: 9m 35s
# 933:	total: 58.5s	remaining: 9m 35s
# 934:	total: 58.5s	remaining: 9m 34s
# 935:	learn: 1.2658859	test: 1.2712833	best: 1.2712833 (935)	total: 58.6s	remaining: 9m 34s
# 936:	total: 58.6s	remaining: 9m 33s
# 937:	total: 58.6s	remaining: 9m 33s
# 938:	total: 58.6s	remaining: 9m 33s
# 939:	total: 58.7s	remaining: 9m 32s
# 940:	learn: 1.2657499	test: 1.2711935	best: 1.2711935 (940)	total: 58.7s	remaining: 9m 32s
# 941:	total: 58.7s	remaining: 9m 31s
# 942:	total: 58.7s	remaining: 9m 31s
# 943:	total: 58.7s	remaining: 9m 31s
# 944:	total: 58.8s	remaining: 9m 31s
# 945:	learn: 1.2655541	test: 1.2710533	best: 1.2710533 (945)	total: 58.8s	remaining: 9m 30s
# 946:	total: 1m 1s	remaining: 9m 55s
# 947:	total: 1m 1s	remaining: 9m 55s
# 948:	total: 1m 1s	remaining: 9m 54s
# 949:	total: 1m 1s	remaining: 9m 54s
# 950:	learn: 1.2653795	test: 1.2709441	best: 1.2709441 (950)	total: 1m 1s	remaining: 9m 53s
# 951:	total: 1m 1s	remaining: 9m 53s
# 952:	total: 1m 1s	remaining: 9m 53s
# 953:	total: 1m 1s	remaining: 9m 52s
# 954:	total: 1m 1s	remaining: 9m 52s
# 955:	learn: 1.2652282	test: 1.2708442	best: 1.2708442 (955)	total: 1m 1s	remaining: 9m 52s
# 956:	total: 1m 1s	remaining: 9m 51s
# 957:	total: 1m 1s	remaining: 9m 51s
# 958:	total: 1m 1s	remaining: 9m 50s
# 959:	total: 1m 1s	remaining: 9m 50s
# 960:	learn: 1.2650777	test: 1.2707487	best: 1.2707487 (960)	total: 1m 1s	remaining: 9m 49s
# 961:	total: 1m 1s	remaining: 9m 49s
# 962:	total: 1m 1s	remaining: 9m 49s
# 963:	total: 1m 1s	remaining: 9m 48s
# 964:	total: 1m 1s	remaining: 9m 48s
# 965:	learn: 1.2649325	test: 1.2706568	best: 1.2706568 (965)	total: 1m 1s	remaining: 9m 47s
# 966:	total: 1m 1s	remaining: 9m 47s
# 967:	total: 1m 1s	remaining: 9m 46s
# 968:	total: 1m 2s	remaining: 9m 46s
# 969:	total: 1m 2s	remaining: 9m 46s
# 970:	learn: 1.2648052	test: 1.2706275	best: 1.2706251 (969)	total: 1m 4s	remaining: 10m 10s
# 971:	total: 1m 4s	remaining: 10m 9s
# 972:	total: 1m 4s	remaining: 10m 9s
# 973:	total: 1m 4s	remaining: 10m 8s
# 974:	total: 1m 4s	remaining: 10m 8s
# 975:	learn: 1.2646646	test: 1.2705300	best: 1.2705300 (975)	total: 1m 4s	remaining: 10m 8s
# 976:	total: 1m 4s	remaining: 10m 7s
# 977:	total: 1m 4s	remaining: 10m 7s
# 978:	total: 1m 4s	remaining: 10m 6s
# 979:	total: 1m 4s	remaining: 10m 6s
# 9970:	learn: 1.1414111	test: 1.2529000	best: 1.2528832 (9966)	total: 8m 56s	remaining: 1.58s
# 9971:	total: 8m 56s	remaining: 1.52s
# 9972:	total: 8m 56s	remaining: 1.47s
# 9973:	total: 8m 56s	remaining: 1.41s
# 9974:	total: 8m 56s	remaining: 1.36s
# 9975:	learn: 1.1413606	test: 1.2528979	best: 1.2528832 (9966)	total: 8m 56s	remaining: 1.3s
# 9976:	total: 8m 56s	remaining: 1.25s
# 9977:	total: 8m 56s	remaining: 1.2s
# 9978:	total: 8m 56s	remaining: 1.14s
# 9979:	total: 8m 56s	remaining: 1.09s
# 9980:	learn: 1.1413084	test: 1.2528891	best: 1.2528832 (9966)	total: 8m 56s	remaining: 1.03s
# 9981:	total: 8m 56s	remaining: 978ms
# 9982:	total: 8m 57s	remaining: 924ms
# 9983:	total: 8m 57s	remaining: 869ms
# 9984:	total: 8m 57s	remaining: 815ms
# 9985:	learn: 1.1412500	test: 1.2528676	best: 1.2528676 (9985)	total: 8m 57s	remaining: 761ms
# 9986:	total: 8m 57s	remaining: 706ms
# 9987:	total: 8m 57s	remaining: 652ms
# 9988:	total: 8m 57s	remaining: 597ms
# 9989:	total: 8m 57s	remaining: 543ms
# 9990:	learn: 1.1411875	test: 1.2528566	best: 1.2528566 (9990)	total: 8m 57s	remaining: 489ms
# 9991:	total: 8m 57s	remaining: 434ms
# 9992:	total: 8m 57s	remaining: 380ms
# 9993:	total: 8m 57s	remaining: 326ms
# 9994:	total: 8m 57s	remaining: 271ms
# 9995:	learn: 1.1411446	test: 1.2528514	best: 1.2528514 (9995)	total: 8m 57s	remaining: 217ms
# 9996:	total: 8m 57s	remaining: 163ms
# 9997:	total: 8m 57s	remaining: 109ms
# 9998:	total: 8m 57s	remaining: 54.3ms
# 9999:	learn: 1.1411045	test: 1.2528513	best: 1.2528507 (9997)	total: 8m 57s	remaining: 0us
# bestTest = 1.252850725
# bestIteration = 9997
# Shrink model to first 9998 iterations.
# 1.2560770713208111 0.008162725228476681

# %%
pd.DataFrame(
    zip(models_list[0].feature_importances_, X_train.columns, strict=False)
).sort_values(by=0, ascending=False).head(10)
# Out:
#              0                                       1
# 1383  3.705580       ts_day_sum_sum__number_peaks__n_1
# 3037  3.460619    ts_full_FULL_amount__quantile__q_0.6
# 2679  3.449445       ts_day_max_max__number_peaks__n_1
# 1398  1.853160  ts_day_sum_sum__cid_ce__normalize_True
# 1590  1.658696  ts_day_sum_sum__number_crossing_m__m_1
# 197   1.222721       ts_month_min_min__quantile__q_0.1
# 3039  1.148171             ts_full_FULL_amount__median
# 3055  1.138320    ts_full_FULL_amount__quantile__q_0.3
# 2658  1.113551         ts_day_max_max__quantile__q_0.4
# 3097  1.033507    ts_full_FULL_amount__quantile__q_0.1

# %%
# Predictions on the test set using probabilities
y_pred_proba = np.zeros(
    (X_test.shape[0], len(np.unique(y_train)))
)  # Assuming classes are 0 to n_classes-1
for model in models_list:
    y_pred_proba += model.predict_proba(X_test)

# Take the class with the maximum summed probability
y_pred = np.argmax(y_pred_proba, axis=1)

# %%
submission["target"] = y_pred
submission.to_csv("submissions/ts_fresh_features_test_2.csv", index=False)
# Out:
# /tmp/ipykernel_210794/4197979530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission["target"] = y_pred

# %%
#     transaction_span_days=("date_time", lambda x: (x.max() - x.min()).days),

#     # Count of transactions in recent periods
#     transactions_last_month=("date_time", lambda x: df_transactions.loc[x.index, 'is_last_month'].sum()),
#     transactions_last_week=("date_time", lambda x: df_transactions.loc[x.index, 'is_last_week'].sum()),
#     transactions_last_two_weeks=("date_time", lambda x: df_transactions.loc[x.index, 'is_last_two_weeks'].sum()),

#     # Additional statistics for amount during specific periods
#     sum_amount_last_month=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_month']].sum()),
#     avg_amount_last_month=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_month']].mean() if df_transactions.loc[x.index, 'is_last_month'].any() else 0),
#     max_amount_last_month=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_month']].max() if df_transactions.loc[x.index, 'is_last_month'].any() else 0),

#     sum_amount_last_week=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_week']].sum()),
#     avg_amount_last_week=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_week']].mean() if df_transactions.loc[x.index, 'is_last_week'].any() else 0),
#     max_amount_last_week=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_week']].max() if df_transactions.loc[x.index, 'is_last_week'].any() else 0),

#     sum_amount_last_two_weeks=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_two_weeks']].sum()),
#     avg_amount_last_two_weeks=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_two_weeks']].mean() if df_transactions.loc[x.index, 'is_last_two_weeks'].any() else 0),
#     max_amount_last_two_weeks=("amount", lambda x: x[df_transactions.loc[x.index, 'is_last_two_weeks']].max() if df_transactions.loc[x.index, 'is_last_two_weeks'].any() else 0)
# )

# %%
# Добавляем количество дней, часов с момента первой и предыдущей транзакций
first_trx = transactions_df.groupby("user_id")["transaction_dttm"].min().reset_index()
first_trx.rename(columns={"transaction_dttm": "first_tr"}, inplace=True)
transactions_df = transactions_df.merge(first_trx, on="user_id", how="left")

transactions_df["days_from_first_tr"] = (
    transactions_df["transaction_dttm"] - transactions_df["first_tr"]
) / np.timedelta64(1, "D")
transactions_df["days_from_first_tr"] = (transactions_df["days_from_first_tr"]).astype(
    "int"
)
transactions_df["days_from_prev_tr"] = transactions_df[
    "transaction_dttm"
].diff() / np.timedelta64(1, "D")
transactions_df["days_from_prev_tr"] = transactions_df["days_from_prev_tr"].fillna(0)

transactions_df["days_from_prev_tr"] = (transactions_df["days_from_prev_tr"]).astype(
    "int"
)

transactions_df["hours_from_first_tr"] = (
    transactions_df["transaction_dttm"] - transactions_df["first_tr"]
) / np.timedelta64(1, "h")
transactions_df["hours_from_prev_tr"] = transactions_df[
    "transaction_dttm"
].diff() / np.timedelta64(1, "h")
transactions_df["hours_from_prev_tr"] = transactions_df["hours_from_prev_tr"].fillna(0)

transactions_df = transactions_df.drop(columns=["first_tr"])
