# %%
from datetime import datetime

import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import StratifiedKFold
from tqdm.notebook import tqdm

df_transactions = pd.read_parquet("data/df_transaction.pa")
df_train = pd.read_parquet("data/train.pa")

# %%
df_transactions = df_transactions.drop("merchant_name", axis=1)

# %%
# time diff features

start_date = datetime.strptime("2024-07-01", "%Y-%m-%d")
current_date = datetime.strptime("2024-10-01", "%Y-%m-%d")

time_features = (
    df_transactions.groupby("client_num")["date_time"].agg(["min", "max"]).reset_index()
)
time_features["history_start"] = start_date
time_features["history_end"] = current_date

time_features["time_between_first_and_last_days"] = (
    time_features["max"] - time_features["min"]
).dt.days
time_features["time_between_first_and_last_hours"] = (
    time_features["max"] - time_features["min"]
).dt.total_seconds() / 3600

time_features["time_between_start_and_first_days"] = (
    time_features["min"] - time_features["history_start"]
).dt.days
time_features["time_between_start_and_first_hours"] = (
    time_features["min"] - time_features["history_start"]
).dt.total_seconds() / 3600

time_features["time_between_last_and_end_days"] = (
    time_features["history_end"] - time_features["max"]
).dt.days
time_features["time_between_last_and_end_hours"] = (
    time_features["history_end"] - time_features["max"]
).dt.total_seconds() / 3600

time_features = time_features.drop(["min", "max", "history_start", "history_end"], axis=1)

# %%
time_features
# Out:
#         client_num  time_between_first_and_last_days  \
# 0                0                                74
# 1                1                                91
# 2                2                                91
# 3                3                                91
# 4                4                                90
# ...            ...                               ...
# 109138      109138                                46
# 109139      109139                                16
# 109140      109140                                45
# 109141      109141                                56
# 109142      109142                                 3
#
#         time_between_first_and_last_hours  time_between_start_and_first_days  \
# 0                             1777.016667                                 17
# 1                             2192.900000                                  0
# 2                             2186.733333                                  0
# 3                             2197.800000                                  0
# 4                             2169.816667                                  1
# ...                                   ...                                ...
# 109138                        1125.816667                                 44
# 109139                         405.466667                                 29
# 109140                        1082.400000                                  5
# 109141                        1351.716667                                  7
# 109142                          78.416667                                 46
#
#         time_between_start_and_first_hours  time_between_last_and_end_days  \
# 0                               424.066667                               0
# 1                                 9.016667                               0
# 2                                16.866667                               0
# 3                                 8.133333                               0
# 4                                34.750000                               0
# ...                                    ...                             ...
# 109138                         1066.816667                               0
# 109139                          710.800000                              45
# 109140                          132.666667                              41
# 109141                          178.383333                              28
# 109142                         1119.783333                              42
#
#         time_between_last_and_end_hours
# 0                              6.916667
# 1                              6.083333
# 2                              4.400000
# 3                              2.066667
# 4                              3.433333
# ...                                 ...
# 109138                        15.366667
# 109139                      1091.733333
# 109140                       992.933333
# 109141                       677.900000
# 109142                      1009.800000
#
# [109143 rows x 7 columns]

# %%
df_transactions
# Out:
#           client_num           date_time mcc_code  amount
# 0                  0 2024-07-18 16:04:00     8099    2900
# 1                  0 2024-07-22 16:31:00     5411     455
# 2                  0 2024-07-24 16:23:00     5541    1003
# 3                  0 2024-07-28 15:51:00     5691    1480
# 4                  0 2024-07-28 18:00:00     5331      88
# ...              ...                 ...      ...     ...
# 13508150      109142 2024-08-19 21:32:00     6011   14000
# 13508151      109142 2024-08-19 21:40:00     6011   24000
# 13508152      109142 2024-08-19 21:46:00     6011   23000
# 13508153      109142 2024-08-19 22:04:00     6011   32000
# 13508154      109142 2024-08-19 22:12:00     6011   34000
#
# [13508155 rows x 4 columns]

# %%
def classify_time(hour):
    if 5 <= hour < 12:
        return "Morning"
    if 12 <= hour < 17:
        return "Afternoon"
    if 17 <= hour < 21:
        return "Evening"
    return "Night"


df_transactions["month"] = df_transactions.date_time.dt.month.astype("int8")
df_transactions["hour"] = df_transactions.date_time.dt.hour.astype("int8")
df_transactions["day_of_month"] = df_transactions.date_time.dt.day.astype("int8")
df_transactions["day_of_week"] = (df_transactions.date_time.dt.dayofweek + 1).astype(
    "int8"
)
df_transactions["is_wknd"] = (df_transactions.date_time.dt.weekday // 4).astype("int8")

df_transactions["time_of_day"] = df_transactions["hour"].apply(classify_time)
top_10_mcc = df_transactions["mcc_code"].value_counts().head(10).index.tolist()
df_transactions["mcc_code_in_top10"] = (
    df_transactions["mcc_code"].isin(top_10_mcc).astype(int)
)

# %%
df_transactions["mcc_code"].nunique()
# Out:
# 320

# %%
df_transactions
# Out:
#           client_num           date_time mcc_code  amount  month  hour  \
# 0                  0 2024-07-18 16:04:00     8099    2900      7    16
# 1                  0 2024-07-22 16:31:00     5411     455      7    16
# 2                  0 2024-07-24 16:23:00     5541    1003      7    16
# 3                  0 2024-07-28 15:51:00     5691    1480      7    15
# 4                  0 2024-07-28 18:00:00     5331      88      7    18
# ...              ...                 ...      ...     ...    ...   ...
# 13508150      109142 2024-08-19 21:32:00     6011   14000      8    21
# 13508151      109142 2024-08-19 21:40:00     6011   24000      8    21
# 13508152      109142 2024-08-19 21:46:00     6011   23000      8    21
# 13508153      109142 2024-08-19 22:04:00     6011   32000      8    22
# 13508154      109142 2024-08-19 22:12:00     6011   34000      8    22
#
#           day_of_month  day_of_week  is_wknd time_of_day  mcc_code_in_top10
# 0                   18            4        0   Afternoon                  0
# 1                   22            1        0   Afternoon                  1
# 2                   24            3        0   Afternoon                  1
# 3                   28            7        1   Afternoon                  0
# 4                   28            7        1     Evening                  0
# ...                ...          ...      ...         ...                ...
# 13508150            19            1        0       Night                  1
# 13508151            19            1        0       Night                  1
# 13508152            19            1        0       Night                  1
# 13508153            19            1        0       Night                  1
# 13508154            19            1        0       Night                  1
#
# [13508155 rows x 11 columns]

# %%
default_features = (
    df_transactions.groupby("client_num")
    .agg(
        {
            "amount": [
                "sum",
                "mean",
                "max",
                "min",
                "std",
                "median",
                "nunique",
            ],
            "mcc_code": [
                "nunique",
                "count",
                lambda x: x.mode()[0],
            ],
            "is_wknd": ["sum", "mean"],
            "hour": ["mean", "std", "max", "min"],
            "day_of_week": ["mean", "std", "max", "min"],
            "mcc_code_in_top10": [
                "sum",
                "mean",
            ],
            "time_of_day": [lambda x: x.mode()[0], "nunique", "count"],
            "day_of_month": ["nunique"],
        }
    )
    .reset_index()
)

default_features.columns = ["_".join(c) for c in default_features.columns]
default_features = default_features.rename(columns={"client_num_": "client_num"})
default_features
# Out:
#         client_num  amount_sum   amount_mean  amount_max  amount_min  \
# 0                0      106935    810.113636        7322          28
# 1                1      863878   3599.491667      100000           6
# 2                2      344108   1147.026667       24496          23
# 3                3     1621825  11032.823129     1000000           1
# 4                4      199796   1637.672131       50000          24
# ...            ...         ...           ...         ...         ...
# 109138      109138      236283  14767.687500       59255           1
# 109139      109139        9640    642.666667        1150          25
# 109140      109140       28389   1577.166667        9900          35
# 109141      109141       61843   3865.187500       22360         170
# 109142      109142      341100  22740.000000       86000         100
#
#           amount_std  amount_median  amount_nunique  mcc_code_nunique  \
# 0        1311.578925          403.0             111                18
# 1       11704.843812          691.5             215                29
# 2        2629.178018          456.0             253                33
# 3       86498.559476          450.0             116                21
# 4        4938.356295          449.5              89                 9
# ...              ...            ...             ...               ...
# 109138  20613.075561         3105.5              16                 4
# 109139    344.028169          710.0              13                 6
# 109140   2679.431749          184.5              14                 5
# 109141   7251.421398          632.5              16                10
# 109142  19589.348418        17000.0              13                 1
#
#         mcc_code_count  ... day_of_week_mean  day_of_week_std  \
# 0                  132  ...         3.969697         2.067337
# 1                  240  ...         4.075000         1.846233
# 2                  300  ...         4.233333         2.049281
# 3                  147  ...         4.142857         1.861653
# 4                  122  ...         3.516393         1.773234
# ...                ...  ...              ...              ...
# 109138              16  ...         2.000000         1.032796
# 109139              15  ...         3.333333         1.234427
# 109140              18  ...         3.388889         2.173067
# 109141              16  ...         3.937500         2.489143
# 109142              15  ...         1.266667         1.032796
#
#         day_of_week_max  day_of_week_min  mcc_code_in_top10_sum  \
# 0                     7                1                    112
# 1                     7                1                    150
# 2                     7                1                    239
# 3                     7                1                     87
# 4                     7                1                     85
# ...                 ...              ...                    ...
# 109138                3                1                      2
# 109139                6                2                     14
# 109140                6                1                      9
# 109141                7                1                     10
# 109142                5                1                     15
#
#         mcc_code_in_top10_mean  time_of_day_<lambda_0>  time_of_day_nunique  \
# 0                     0.848485                 Evening                    4
# 1                     0.625000                 Evening                    4
# 2                     0.796667               Afternoon                    4
# 3                     0.591837                 Morning                    4
# 4                     0.696721                 Evening                    4
# ...                        ...                     ...                  ...
# 109138                0.125000                 Morning                    2
# 109139                0.933333               Afternoon                    3
# 109140                0.500000               Afternoon                    2
# 109141                0.625000               Afternoon                    3
# 109142                1.000000                   Night                    3
#
#         time_of_day_count  day_of_month_nunique
# 0                     132                    31
# 1                     240                    31
# 2                     300                    31
# 3                     147                    31
# 4                     122                    29
# ...                   ...                   ...
# 109138                 16                     5
# 109139                 15                     8
# 109140                 18                     7
# 109141                 16                    11
# 109142                 15                     2
#
# [109143 rows x 27 columns]

# %%
def get_features(columns):
    features = df_transactions.pivot_table(
        index="client_num",
        columns=columns,
        values="amount",
        aggfunc=["sum", "mean", "count", "std", "min", "max", "median"],
        fill_value=0,
    )
    features.columns = [f"{columns}_{i[1]}_{i[0]}" for i in features.columns]
    features = features.reset_index()
    return features


month_features = get_features("month")
day_of_month_features = get_features("day_of_month")
day_of_week_features = get_features("day_of_week")
time_of_day_features = get_features("time_of_day")
hour_features = get_features("hour")
is_wknd_features = get_features("is_wknd")

# %%
def get_fraction(columns, aggfunc):

    pt = df_transactions.pivot_table(
        index="client_num",
        columns=columns,
        values="amount",
        aggfunc=aggfunc,
        fill_value=0,
    )

    result = pt.div(pt.sum(axis=1), axis=0)
    result.columns = [f"fraction_{columns}_{aggfunc}_{col}" for col in result.columns]
    result = result.reset_index()

    return result


month_fraction_sum = get_fraction("month", "sum")
month_fraction_count = get_fraction("month", "count")

day_of_month_fraction_sum = get_fraction("day_of_month", "sum")
day_of_month_fraction_count = get_fraction("day_of_month", "count")

day_of_week_fraction_sum = get_fraction("day_of_week", "sum")
day_of_week_fraction_count = get_fraction("day_of_week", "count")

time_of_day_fraction_sum = get_fraction("time_of_day", "sum")
time_of_day_fraction_count = get_fraction("time_of_day", "count")

hour_fraction_sum = get_fraction("hour", "sum")
hour_fraction_count = get_fraction("hour", "count")

is_wknd_fraction_sum = get_fraction("is_wknd", "sum")
is_wknd_fraction_count = get_fraction("is_wknd", "count")

mcc_code_fraction_sum = get_fraction("mcc_code", "sum")
mcc_code_fraction_count = get_fraction("mcc_code", "count")

mcc_code_in_top10_fraction_sum = get_fraction("mcc_code_in_top10", "sum")
mcc_code_in_top10_fraction_count = get_fraction("mcc_code_in_top10", "count")

# %%
df_transactions["date_time"] = pd.to_datetime(df_transactions["date_time"])
df_transactions = df_transactions.sort_values(by=["client_num", "date_time"])
df_transactions["time_diff"] = (
    df_transactions.groupby("client_num")["date_time"].diff().dt.total_seconds()
)
df_transactions["time_diff_hours"] = df_transactions["time_diff"] / 3600
time_diff_features = (
    df_transactions.groupby("client_num")["time_diff_hours"]
    .agg(["max", "min", "mean"])
    .reset_index()
)

# %%
combined_df = pd.concat(
    [
        default_features,
        time_features,
        month_features,
        day_of_month_features,
        day_of_week_features,
        time_of_day_features,
        hour_features,
        is_wknd_features,
        month_fraction_sum,
        month_fraction_count,
        day_of_month_fraction_sum,
        day_of_month_fraction_count,
        day_of_week_fraction_sum,
        day_of_week_fraction_count,
        time_of_day_fraction_sum,
        time_of_day_fraction_count,
        hour_fraction_sum,
        hour_fraction_count,
        is_wknd_fraction_sum,
        is_wknd_fraction_count,
        mcc_code_fraction_sum,
        mcc_code_fraction_count,
        mcc_code_in_top10_fraction_sum,
        mcc_code_in_top10_fraction_count,
        time_diff_features,
    ],
    axis=1,
)
combined_df = combined_df.loc[:, ~combined_df.columns.duplicated()]

# %%
combined_df.to_pickle("data/features/heuristics.pkl")

# %%
test_clients = list(
    set(df_transactions["client_num"].unique().tolist()).difference(
        df_train["client_num"].to_list()
    )
)

# %%
X_train = df_train.merge(
    combined_df[~combined_df["client_num"].isin(test_clients)],
    left_on="client_num",
    right_on="client_num",
    how="left",
)
X_test = combined_df[combined_df["client_num"].isin(test_clients)]

y_train = X_train["target"]
submission = X_test[["client_num"]]

X_train = X_train.drop(["client_num", "target"], axis=1)
X_test = X_test.drop("client_num", axis=1)

# %%
CAT_FEATURES = X_train.select_dtypes("object").columns.to_list()
EARLY_STOPPING = 400
EVAL_METRIC = "MAE"

models_list = []
scores_list = []

splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for i, (train_index, test_index) in tqdm(enumerate(splitter.split(X_train, y_train))):
    X_fold_train, y_fold_train = X_train.iloc[train_index], y_train.iloc[train_index]
    X_fold_test, y_fold_test = X_train.iloc[test_index], y_train.iloc[test_index]

    model = CatBoostRegressor(
        iterations=10000,
        loss_function="MAE",
        cat_features=CAT_FEATURES,
        learning_rate=0.03,
        depth=4,
        # verbose=0,
        eval_metric=EVAL_METRIC,
        early_stopping_rounds=EARLY_STOPPING,
        task_type="GPU",
        # depth=4,
    )

    model.fit(X_fold_train, y_fold_train, eval_set=(X_fold_test, y_fold_test))
    preds = model.predict(X_fold_test)

    score = mean_absolute_error(y_fold_test, preds)

    models_list.append(model)
    scores_list.append(score)

print(np.mean(scores_list), np.std(scores_list))
# Out:
# 0it [00:00, ?it/s]
# Default metric period is 5 because MAE is/are not implemented for GPU
# 0:	learn: 1.5806078	test: 1.5802698	best: 1.5802698 (0)	total: 99.2ms	remaining: 16m 31s
# 1:	total: 122ms	remaining: 10m 8s
# 2:	total: 145ms	remaining: 8m 4s
# 3:	total: 164ms	remaining: 6m 50s
# 4:	total: 183ms	remaining: 6m 4s
# 5:	learn: 1.5735287	test: 1.5731352	best: 1.5731352 (5)	total: 200ms	remaining: 5m 33s
# 6:	total: 218ms	remaining: 5m 10s
# 7:	total: 237ms	remaining: 4m 56s
# 8:	total: 255ms	remaining: 4m 43s
# 9:	total: 255ms	remaining: 4m 43s
# 10:	learn: 1.5668777	test: 1.5663503	best: 1.5663503 (10)	total: 2.88s	remaining: 47m 59s
# 11:	total: 2.9s	remaining: 43m 53s
# 12:	total: 2.92s	remaining: 40m 31s
# 13:	total: 2.94s	remaining: 37m 39s
# 14:	total: 2.96s	remaining: 35m 10s
# 15:	learn: 1.5600124	test: 1.5592952	best: 1.5592952 (15)	total: 2.96s	remaining: 35m 10s
# 16:	total: 5.58s	remaining: 1h 1m 56s
# 17:	total: 5.6s	remaining: 58m 15s
# 18:	total: 5.62s	remaining: 54m 59s
# 19:	total: 5.62s	remaining: 54m 59s
# 20:	learn: 1.5532595	test: 1.5524403	best: 1.5524403 (20)	total: 8.25s	remaining: 1h 16m 12s
# 21:	total: 8.27s	remaining: 1h 12m 20s
# 22:	total: 8.28s	remaining: 1h 8m 52s
# 23:	total: 8.3s	remaining: 1h 5m 43s
# 24:	total: 8.32s	remaining: 1h 2m 53s
# 25:	learn: 1.5465361	test: 1.5455603	best: 1.5455603 (25)	total: 8.34s	remaining: 1h 16s
# 26:	total: 8.36s	remaining: 57m 52s
# 27:	total: 8.37s	remaining: 55m 39s
# 28:	total: 8.39s	remaining: 53m 37s
# 29:	total: 8.41s	remaining: 51m 45s
# 30:	learn: 1.5397529	test: 1.5387125	best: 1.5387125 (30)	total: 8.43s	remaining: 50m
# 31:	total: 8.45s	remaining: 48m 23s
# 32:	total: 8.46s	remaining: 46m 51s
# 33:	total: 8.48s	remaining: 45m 27s
# 34:	total: 8.5s	remaining: 44m 7s
# 35:	learn: 1.5330232	test: 1.5319464	best: 1.5319464 (35)	total: 8.52s	remaining: 42m 52s
# 36:	total: 8.54s	remaining: 41m 42s
# 37:	total: 8.56s	remaining: 40m 35s
# 38:	total: 8.57s	remaining: 39m 32s
# 39:	total: 8.59s	remaining: 38m 33s
# 40:	learn: 1.5263230	test: 1.5251787	best: 1.5251787 (40)	total: 8.61s	remaining: 37m 36s
# 41:	total: 8.63s	remaining: 36m 43s
# 42:	total: 8.64s	remaining: 35m 51s
# 43:	total: 8.66s	remaining: 35m 3s
# 44:	total: 8.68s	remaining: 34m 17s
# 45:	learn: 1.5196249	test: 1.5183262	best: 1.5183262 (45)	total: 8.7s	remaining: 33m 33s
# 46:	total: 8.71s	remaining: 32m 50s
# 47:	total: 8.73s	remaining: 32m 10s
# 48:	total: 8.75s	remaining: 31m 32s
# 49:	total: 8.77s	remaining: 30m 55s
# 50:	learn: 1.5130325	test: 1.5116225	best: 1.5116225 (50)	total: 8.78s	remaining: 30m 20s
# 51:	total: 8.8s	remaining: 29m 46s
# 52:	total: 8.82s	remaining: 29m 14s
# 53:	total: 8.84s	remaining: 28m 43s
# 54:	total: 8.86s	remaining: 28m 13s
# 55:	learn: 1.5063062	test: 1.5048394	best: 1.5048394 (55)	total: 8.87s	remaining: 27m 44s
# 56:	total: 8.87s	remaining: 27m 44s
# 57:	total: 11.5s	remaining: 35m 17s
# 58:	total: 11.5s	remaining: 34m 41s
# 59:	total: 11.5s	remaining: 34m 7s
# 60:	learn: 1.4995633	test: 1.4980273	best: 1.4980273 (60)	total: 11.6s	remaining: 33m 36s
# 61:	total: 11.6s	remaining: 33m 7s
# 62:	total: 11.6s	remaining: 32m 38s
# 63:	total: 11.6s	remaining: 32m 9s
# 64:	total: 11.7s	remaining: 31m 40s
# 65:	learn: 1.4929499	test: 1.4912977	best: 1.4912977 (65)	total: 11.7s	remaining: 31m 13s
# 66:	total: 11.7s	remaining: 30m 46s
# 67:	total: 11.7s	remaining: 30m 20s
# 68:	total: 11.8s	remaining: 29m 56s
# 69:	total: 11.8s	remaining: 29m 31s
# 70:	learn: 1.4862826	test: 1.4844999	best: 1.4844999 (70)	total: 11.8s	remaining: 29m 7s
# 71:	total: 11.8s	remaining: 28m 44s
# 72:	total: 11.8s	remaining: 28m 21s
# 73:	total: 11.8s	remaining: 27m 59s
# 74:	total: 11.9s	remaining: 27m 37s
# 75:	learn: 1.4794044	test: 1.4775371	best: 1.4775371 (75)	total: 11.9s	remaining: 27m 16s
# 76:	total: 11.9s	remaining: 26m 56s
# 77:	total: 11.9s	remaining: 26m 36s
# 78:	total: 11.9s	remaining: 26m 17s
# 79:	total: 11.9s	remaining: 25m 58s
# 80:	learn: 1.4727616	test: 1.4708013	best: 1.4708013 (80)	total: 12s	remaining: 25m 40s
# 81:	total: 12s	remaining: 25m 22s
# 82:	total: 12s	remaining: 25m 4s
# 83:	total: 12s	remaining: 24m 48s
# 84:	total: 12s	remaining: 24m 31s
# 85:	learn: 1.4658397	test: 1.4637335	best: 1.4637335 (85)	total: 12s	remaining: 24m 15s
# 86:	total: 12.1s	remaining: 23m 59s
# 87:	total: 12.1s	remaining: 23m 44s
# 88:	total: 12.1s	remaining: 23m 29s
# 89:	total: 12.1s	remaining: 23m 15s
# 90:	learn: 1.4589973	test: 1.4567603	best: 1.4567603 (90)	total: 12.1s	remaining: 23m
# 91:	total: 12.1s	remaining: 22m 46s
# 92:	total: 12.2s	remaining: 22m 32s
# 93:	total: 12.2s	remaining: 22m 19s
# 94:	total: 12.2s	remaining: 22m 7s
# 95:	learn: 1.4523052	test: 1.4500151	best: 1.4500151 (95)	total: 12.2s	remaining: 21m 54s
# 96:	total: 12.2s	remaining: 21m 42s
# 97:	total: 12.2s	remaining: 21m 30s
# 98:	total: 12.3s	remaining: 21m 18s
# 99:	total: 12.3s	remaining: 21m 7s
# 100:	learn: 1.4456279	test: 1.4432448	best: 1.4432448 (100)	total: 12.3s	remaining: 20m 55s
# 101:	total: 12.3s	remaining: 20m 44s
# 102:	total: 12.3s	remaining: 20m 33s
# 103:	total: 12.4s	remaining: 20m 23s
# 104:	total: 12.4s	remaining: 20m 12s
# 105:	learn: 1.4388514	test: 1.4363799	best: 1.4363799 (105)	total: 12.4s	remaining: 20m 2s
# 106:	total: 12.4s	remaining: 19m 52s
# 107:	total: 12.4s	remaining: 19m 42s
# 108:	total: 12.4s	remaining: 19m 32s
# 109:	total: 12.5s	remaining: 19m 23s
# 110:	learn: 1.4322772	test: 1.4297023	best: 1.4297023 (110)	total: 12.5s	remaining: 19m 14s
# 111:	total: 12.5s	remaining: 19m 4s
# 112:	total: 12.5s	remaining: 18m 55s
# 113:	total: 12.5s	remaining: 18m 47s
# 114:	total: 12.6s	remaining: 18m 38s
# 115:	learn: 1.4254895	test: 1.4227839	best: 1.4227839 (115)	total: 12.6s	remaining: 18m 30s
# 116:	total: 12.6s	remaining: 18m 21s
# 117:	total: 12.6s	remaining: 18m 13s
# 118:	total: 12.6s	remaining: 18m 5s
# 119:	total: 12.7s	remaining: 17m 57s
# 120:	learn: 1.4188372	test: 1.4160054	best: 1.4160054 (120)	total: 12.7s	remaining: 17m 49s
# 121:	total: 12.7s	remaining: 17m 42s
# 122:	total: 12.7s	remaining: 17m 34s
# 123:	total: 12.7s	remaining: 17m 27s
# 124:	total: 12.7s	remaining: 17m 20s
# 125:	learn: 1.4123903	test: 1.4094089	best: 1.4094089 (125)	total: 12.8s	remaining: 17m 13s
# 126:	total: 12.8s	remaining: 17m 6s
# 127:	total: 12.8s	remaining: 16m 59s
# 128:	total: 12.8s	remaining: 16m 52s
# 129:	total: 12.8s	remaining: 16m 45s
# 130:	learn: 1.4062720	test: 1.4031832	best: 1.4031832 (130)	total: 12.9s	remaining: 16m 39s
# 131:	total: 12.9s	remaining: 16m 32s
# 132:	total: 12.9s	remaining: 16m 26s
# 133:	total: 12.9s	remaining: 16m 19s
# 134:	total: 12.9s	remaining: 16m 13s
# 135:	learn: 1.4002524	test: 1.3970698	best: 1.3970698 (135)	total: 12.9s	remaining: 16m 7s
# 136:	total: 13s	remaining: 16m 1s
# 137:	total: 13s	remaining: 15m 55s
# 138:	total: 13s	remaining: 15m 49s
# 139:	total: 13s	remaining: 15m 44s
# 140:	learn: 1.3946772	test: 1.3913824	best: 1.3913824 (140)	total: 13s	remaining: 15m 38s
# 141:	total: 13.1s	remaining: 15m 32s
# 142:	total: 13.1s	remaining: 15m 27s
# 143:	total: 13.1s	remaining: 15m 21s
# 144:	total: 13.1s	remaining: 15m 16s
# 145:	learn: 1.3896855	test: 1.3863551	best: 1.3863551 (145)	total: 13.1s	remaining: 15m 11s
# 146:	total: 13.1s	remaining: 15m 5s
# 147:	total: 13.2s	remaining: 15m
# 148:	total: 13.2s	remaining: 14m 55s
# 149:	total: 13.2s	remaining: 14m 50s
# 150:	learn: 1.3849385	test: 1.3816613	best: 1.3816613 (150)	total: 13.2s	remaining: 14m 45s
# 151:	total: 13.2s	remaining: 14m 41s
# 152:	total: 13.3s	remaining: 14m 36s
# 153:	total: 13.3s	remaining: 14m 31s
# 154:	total: 13.3s	remaining: 14m 26s
# 155:	learn: 1.3805361	test: 1.3773710	best: 1.3773710 (155)	total: 13.3s	remaining: 14m 21s
# 156:	total: 13.3s	remaining: 14m 17s
# 157:	total: 13.3s	remaining: 14m 12s
# 158:	total: 13.4s	remaining: 14m 8s
# 159:	total: 13.4s	remaining: 14m 8s
# 160:	learn: 1.3765540	test: 1.3734081	best: 1.3734081 (160)	total: 13.4s	remaining: 14m 3s
# 161:	total: 13.4s	remaining: 13m 59s
# 162:	total: 13.4s	remaining: 13m 55s
# 163:	total: 13.4s	remaining: 13m 50s
# 164:	total: 13.4s	remaining: 13m 46s
# 165:	learn: 1.3727701	test: 1.3696645	best: 1.3696645 (165)	total: 13.4s	remaining: 13m 46s
# 166:	total: 13.5s	remaining: 13m 42s
# 167:	total: 13.5s	remaining: 13m 38s
# 168:	total: 16.1s	remaining: 16m 11s
# 169:	total: 16.1s	remaining: 16m 11s
# 170:	learn: 1.3692575	test: 1.3661509	best: 1.3661509 (170)	total: 16.1s	remaining: 16m 6s
# 171:	total: 16.1s	remaining: 16m 1s
# 172:	total: 18.8s	remaining: 18m 31s
# 173:	total: 18.8s	remaining: 18m 25s
# 174:	total: 18.8s	remaining: 18m 19s
# 175:	learn: 1.3661024	test: 1.3630073	best: 1.3630073 (175)	total: 18.8s	remaining: 18m 14s
# 176:	total: 18.8s	remaining: 18m 8s
# 177:	total: 18.9s	remaining: 18m 3s
# 178:	total: 18.9s	remaining: 17m 57s
# 179:	total: 18.9s	remaining: 17m 52s
# 180:	learn: 1.3631193	test: 1.3600179	best: 1.3600179 (180)	total: 18.9s	remaining: 17m 46s
# 181:	total: 18.9s	remaining: 17m 41s
# 182:	total: 18.9s	remaining: 17m 36s
# 183:	total: 19s	remaining: 17m 31s
# 184:	total: 19s	remaining: 17m 31s
# 185:	learn: 1.3603998	test: 1.3573506	best: 1.3573506 (185)	total: 21.6s	remaining: 19m 50s
# 186:	total: 21.6s	remaining: 19m 44s
# 187:	total: 21.6s	remaining: 19m 38s
# 188:	total: 21.6s	remaining: 19m 32s
# 189:	total: 21.7s	remaining: 19m 27s
# 190:	learn: 1.3577532	test: 1.3547909	best: 1.3547909 (190)	total: 21.7s	remaining: 19m 27s
# 191:	total: 24.3s	remaining: 21m 41s
# 192:	total: 24.3s	remaining: 21m 35s
# 193:	total: 24.3s	remaining: 21m 35s
# 194:	total: 26.9s	remaining: 23m 46s
# 195:	learn: 1.3552976	test: 1.3524104	best: 1.3524104 (195)	total: 26.9s	remaining: 23m 40s
# 196:	total: 27s	remaining: 23m 33s
# 197:	total: 27s	remaining: 23m 26s
# 198:	total: 27s	remaining: 23m 19s
# 199:	total: 27s	remaining: 23m 13s
# 200:	learn: 1.3529050	test: 1.3500894	best: 1.3500894 (200)	total: 27s	remaining: 23m 6s
# 201:	total: 27s	remaining: 23m
# 202:	total: 27.1s	remaining: 22m 53s
# 203:	total: 27.1s	remaining: 22m 47s
# 204:	total: 27.1s	remaining: 22m 41s
# 205:	learn: 1.3506607	test: 1.3479549	best: 1.3479549 (205)	total: 27.1s	remaining: 22m 35s
# 206:	total: 27.1s	remaining: 22m 28s
# 207:	total: 27.2s	remaining: 22m 22s
# 208:	total: 27.2s	remaining: 22m 16s
# 209:	total: 27.2s	remaining: 22m 10s
# 210:	learn: 1.3484167	test: 1.3458047	best: 1.3458047 (210)	total: 27.2s	remaining: 22m 4s
# 211:	total: 27.2s	remaining: 21m 59s
# 212:	total: 27.2s	remaining: 21m 53s
# 213:	total: 27.3s	remaining: 21m 47s
# 214:	total: 27.3s	remaining: 21m 42s
# 215:	learn: 1.3463359	test: 1.3438884	best: 1.3438884 (215)	total: 27.3s	remaining: 21m 36s
# 216:	total: 27.3s	remaining: 21m 30s
# 217:	total: 27.3s	remaining: 21m 25s
# 218:	total: 27.3s	remaining: 21m 19s
# 219:	total: 27.4s	remaining: 21m 14s
# 220:	learn: 1.3443359	test: 1.3419634	best: 1.3419634 (220)	total: 27.4s	remaining: 21m 9s
# 221:	total: 27.4s	remaining: 21m 9s
# 222:	total: 30s	remaining: 23m 3s
# 223:	total: 30s	remaining: 22m 58s
# 224:	total: 30s	remaining: 22m 58s
# 225:	learn: 1.3423203	test: 1.3400449	best: 1.3400449 (225)	total: 32.7s	remaining: 24m 51s
# 226:	total: 32.7s	remaining: 24m 51s
# 227:	total: 35.3s	remaining: 26m 43s
# 228:	total: 35.3s	remaining: 26m 36s
# 229:	total: 35.3s	remaining: 26m 30s
# 230:	learn: 1.3403721	test: 1.3381341	best: 1.3381341 (230)	total: 35.3s	remaining: 26m 23s
# 231:	total: 35.4s	remaining: 26m 16s
# 232:	total: 35.4s	remaining: 26m 10s
# 233:	total: 35.4s	remaining: 26m 3s
# 234:	total: 35.4s	remaining: 25m 57s
# 235:	learn: 1.3385218	test: 1.3363186	best: 1.3363186 (235)	total: 35.4s	remaining: 25m 51s
# 236:	total: 35.4s	remaining: 25m 44s
# 237:	total: 35.5s	remaining: 25m 38s
# 238:	total: 35.5s	remaining: 25m 32s
# 239:	total: 35.5s	remaining: 25m 26s
# 240:	learn: 1.3366469	test: 1.3345032	best: 1.3345032 (240)	total: 35.5s	remaining: 25m 19s
# 241:	total: 35.5s	remaining: 25m 14s
# 242:	total: 35.5s	remaining: 25m 8s
# 243:	total: 35.6s	remaining: 25m 2s
# 244:	total: 35.6s	remaining: 24m 56s
# 245:	learn: 1.3348011	test: 1.3327307	best: 1.3327307 (245)	total: 35.6s	remaining: 24m 50s
# 246:	total: 35.6s	remaining: 24m 44s
# 247:	total: 35.6s	remaining: 24m 39s
# 248:	total: 35.7s	remaining: 24m 33s
# 249:	total: 35.7s	remaining: 24m 27s
# 250:	learn: 1.3332157	test: 1.3312930	best: 1.3312930 (250)	total: 35.7s	remaining: 24m 22s
# 251:	total: 35.7s	remaining: 24m 16s
# 252:	total: 35.7s	remaining: 24m 10s
# 253:	total: 35.7s	remaining: 24m 5s
# 254:	total: 35.8s	remaining: 24m
# 255:	learn: 1.3316787	test: 1.3299057	best: 1.3299057 (255)	total: 35.8s	remaining: 23m 54s
# 256:	total: 35.8s	remaining: 23m 49s
# 257:	total: 35.8s	remaining: 23m 44s
# 258:	total: 35.8s	remaining: 23m 39s
# 259:	total: 35.9s	remaining: 23m 33s
# 260:	learn: 1.3302021	test: 1.3285988	best: 1.3285988 (260)	total: 35.9s	remaining: 23m 33s
# 261:	total: 38.5s	remaining: 25m 11s
# 262:	total: 38.5s	remaining: 25m 5s
# 263:	total: 38.5s	remaining: 24m 59s
# 264:	total: 38.5s	remaining: 24m 59s
# 265:	learn: 1.3286465	test: 1.3272224	best: 1.3272224 (265)	total: 38.5s	remaining: 24m 54s
# 266:	total: 38.5s	remaining: 24m 48s
# 267:	total: 41.2s	remaining: 26m 23s
# 268:	total: 41.2s	remaining: 26m 18s
# 269:	total: 41.2s	remaining: 26m 12s
# 270:	learn: 1.3272063	test: 1.3258809	best: 1.3258809 (270)	total: 41.2s	remaining: 26m 12s
# 271:	total: 43.8s	remaining: 27m 45s
# 272:	total: 43.9s	remaining: 27m 39s
# 273:	total: 43.9s	remaining: 27m 33s
# 274:	total: 43.9s	remaining: 27m 27s
# 275:	learn: 1.3257571	test: 1.3245388	best: 1.3245388 (275)	total: 43.9s	remaining: 27m 21s
# 276:	total: 43.9s	remaining: 27m 21s
# 277:	total: 46.5s	remaining: 28m 52s
# 278:	total: 46.5s	remaining: 28m 46s
# 279:	total: 46.6s	remaining: 28m 40s
# 280:	learn: 1.3244156	test: 1.3233426	best: 1.3233426 (280)	total: 46.6s	remaining: 28m 40s
# 281:	total: 46.6s	remaining: 28m 34s
# 282:	total: 46.6s	remaining: 28m 28s
# 283:	total: 46.6s	remaining: 28m 22s
# 284:	total: 49.2s	remaining: 29m 51s
# 285:	learn: 1.3230741	test: 1.3221447	best: 1.3221447 (285)	total: 49.2s	remaining: 29m 44s
# 286:	total: 49.3s	remaining: 29m 38s
# 287:	total: 49.3s	remaining: 29m 32s
# 288:	total: 49.3s	remaining: 29m 26s
# 289:	total: 49.3s	remaining: 29m 20s
# 290:	learn: 1.3216691	test: 1.3208460	best: 1.3208460 (290)	total: 49.3s	remaining: 29m 14s
# 291:	total: 49.3s	remaining: 29m 8s
# 292:	total: 49.4s	remaining: 29m 2s
# 293:	total: 49.4s	remaining: 28m 56s
# 294:	total: 49.4s	remaining: 28m 50s
# 295:	learn: 1.3203389	test: 1.3196906	best: 1.3196906 (295)	total: 49.4s	remaining: 28m 44s
# 296:	total: 49.4s	remaining: 28m 39s
# 297:	total: 49.4s	remaining: 28m 33s
# 298:	total: 49.5s	remaining: 28m 27s
# 299:	total: 49.5s	remaining: 28m 21s
# 300:	learn: 1.3190285	test: 1.3184791	best: 1.3184791 (300)	total: 49.5s	remaining: 28m 16s
# 301:	total: 49.5s	remaining: 28m 10s
# 302:	total: 49.5s	remaining: 28m 5s
# 303:	total: 49.5s	remaining: 27m 59s
# 304:	total: 49.6s	remaining: 27m 54s
# 305:	learn: 1.3177736	test: 1.3173973	best: 1.3173973 (305)	total: 49.6s	remaining: 27m 48s
# 306:	total: 49.6s	remaining: 27m 43s
# 307:	total: 49.6s	remaining: 27m 38s
# 308:	total: 49.6s	remaining: 27m 32s
# 309:	total: 49.6s	remaining: 27m 27s
# 310:	learn: 1.3165819	test: 1.3163320	best: 1.3163320 (310)	total: 49.7s	remaining: 27m 22s
# 311:	total: 49.7s	remaining: 27m 17s
# 312:	total: 49.7s	remaining: 27m 12s
# 313:	total: 49.7s	remaining: 27m 6s
# 314:	total: 49.7s	remaining: 27m 1s
# 315:	learn: 1.3153754	test: 1.3152934	best: 1.3152934 (315)	total: 49.8s	remaining: 26m 56s
# 316:	total: 49.8s	remaining: 26m 51s
# 317:	total: 49.8s	remaining: 26m 46s
# 318:	total: 49.8s	remaining: 26m 41s
# 319:	total: 49.8s	remaining: 26m 37s
# 320:	learn: 1.3142319	test: 1.3142732	best: 1.3142732 (320)	total: 49.8s	remaining: 26m 32s
# 321:	total: 49.9s	remaining: 26m 27s
# 322:	total: 49.9s	remaining: 26m 22s
# 323:	total: 49.9s	remaining: 26m 17s
# 324:	total: 49.9s	remaining: 26m 12s
# 325:	learn: 1.3130862	test: 1.3132995	best: 1.3132995 (325)	total: 49.9s	remaining: 26m 8s
# 326:	total: 49.9s	remaining: 26m 3s
# 327:	total: 50s	remaining: 25m 58s
# 328:	total: 50s	remaining: 25m 54s
# 329:	total: 50s	remaining: 25m 49s
# 330:	learn: 1.3119248	test: 1.3122609	best: 1.3122609 (330)	total: 50s	remaining: 25m 44s
# 331:	total: 50s	remaining: 25m 40s
# 332:	total: 50s	remaining: 25m 35s
# 333:	total: 50.1s	remaining: 25m 31s
# 334:	total: 50.1s	remaining: 25m 26s
# 335:	learn: 1.3108192	test: 1.3112905	best: 1.3112905 (335)	total: 50.1s	remaining: 25m 22s
# 336:	total: 50.1s	remaining: 25m 18s
# 337:	total: 50.1s	remaining: 25m 13s
# 338:	total: 50.2s	remaining: 25m 9s
# 339:	total: 50.2s	remaining: 25m 5s
# 340:	learn: 1.3097547	test: 1.3103315	best: 1.3103315 (340)	total: 50.2s	remaining: 25m
# 341:	total: 50.2s	remaining: 24m 56s
# 342:	total: 50.2s	remaining: 24m 52s
# 343:	total: 50.2s	remaining: 24m 48s
# 344:	total: 50.3s	remaining: 24m 43s
# 345:	learn: 1.3087652	test: 1.3094694	best: 1.3094694 (345)	total: 50.3s	remaining: 24m 39s
# 346:	total: 50.3s	remaining: 24m 35s
# 347:	total: 50.3s	remaining: 24m 31s
# 348:	total: 50.3s	remaining: 24m 27s
# 349:	total: 50.3s	remaining: 24m 23s
# 350:	learn: 1.3077254	test: 1.3085385	best: 1.3085385 (350)	total: 50.4s	remaining: 24m 19s
# 351:	total: 50.4s	remaining: 24m 15s
# 352:	total: 50.4s	remaining: 24m 11s
# 353:	total: 50.4s	remaining: 24m 7s
# 354:	total: 50.4s	remaining: 24m 3s
# 355:	learn: 1.3067723	test: 1.3077185	best: 1.3077185 (355)	total: 50.4s	remaining: 23m 59s
# 356:	total: 50.5s	remaining: 23m 55s
# 357:	total: 50.5s	remaining: 23m 51s
# 358:	total: 50.5s	remaining: 23m 47s
# 359:	total: 50.5s	remaining: 23m 43s
# 360:	learn: 1.3058894	test: 1.3069357	best: 1.3069357 (360)	total: 50.5s	remaining: 23m 39s
# 361:	total: 50.5s	remaining: 23m 36s
# 362:	total: 50.6s	remaining: 23m 32s
# 363:	total: 50.6s	remaining: 23m 28s
# 364:	total: 50.6s	remaining: 23m 24s
# 365:	learn: 1.3049342	test: 1.3061159	best: 1.3061159 (365)	total: 50.6s	remaining: 23m 21s
# 366:	total: 50.6s	remaining: 23m 17s
# 367:	total: 50.6s	remaining: 23m 13s
# 368:	total: 50.7s	remaining: 23m 10s
# 369:	total: 50.7s	remaining: 23m 6s
# 370:	learn: 1.3040578	test: 1.3053781	best: 1.3053781 (370)	total: 50.7s	remaining: 23m 2s
# 371:	total: 50.7s	remaining: 22m 59s
# 372:	total: 50.7s	remaining: 22m 55s
# 373:	total: 50.8s	remaining: 22m 52s
# 374:	total: 50.8s	remaining: 22m 48s
# 375:	learn: 1.3031394	test: 1.3045626	best: 1.3045626 (375)	total: 50.8s	remaining: 22m 45s
# 376:	total: 50.8s	remaining: 22m 41s
# 377:	total: 50.8s	remaining: 22m 38s
# 378:	total: 50.8s	remaining: 22m 35s
# 379:	total: 50.9s	remaining: 22m 31s
# 380:	learn: 1.3022404	test: 1.3037706	best: 1.3037706 (380)	total: 50.9s	remaining: 22m 28s
# 381:	total: 50.9s	remaining: 22m 24s
# 382:	total: 50.9s	remaining: 22m 21s
# 383:	total: 50.9s	remaining: 22m 18s
# 384:	total: 50.9s	remaining: 22m 14s
# 385:	learn: 1.3014661	test: 1.3031232	best: 1.3031232 (385)	total: 51s	remaining: 22m 11s
# 386:	total: 51s	remaining: 22m 8s
# 387:	total: 51s	remaining: 22m 4s
# 388:	total: 51s	remaining: 22m 1s
# 389:	total: 51s	remaining: 21m 58s
# 390:	learn: 1.3006583	test: 1.3024457	best: 1.3024457 (390)	total: 51s	remaining: 21m 55s
# 391:	total: 51.1s	remaining: 21m 51s
# 392:	total: 51.1s	remaining: 21m 48s
# 393:	total: 51.1s	remaining: 21m 45s
# 394:	total: 51.1s	remaining: 21m 42s
# 395:	learn: 1.2997937	test: 1.3016950	best: 1.3016950 (395)	total: 51.1s	remaining: 21m 39s
# 396:	total: 51.2s	remaining: 21m 36s
# 397:	total: 51.2s	remaining: 21m 33s
# 398:	total: 51.2s	remaining: 21m 30s
# 399:	total: 51.2s	remaining: 21m 26s
# 400:	learn: 1.2990324	test: 1.3010130	best: 1.3010130 (400)	total: 51.2s	remaining: 21m 23s
# 401:	total: 51.2s	remaining: 21m 20s
# 402:	total: 51.3s	remaining: 21m 17s
# 403:	total: 51.3s	remaining: 21m 14s
# 404:	total: 51.3s	remaining: 21m 11s
# 405:	learn: 1.2983185	test: 1.3004116	best: 1.3004116 (405)	total: 51.3s	remaining: 21m 8s
# 406:	total: 51.3s	remaining: 21m 5s
# 407:	total: 51.4s	remaining: 21m 2s
# 408:	total: 51.4s	remaining: 21m
# 409:	total: 51.4s	remaining: 20m 57s
# 410:	learn: 1.2975749	test: 1.2997718	best: 1.2997718 (410)	total: 51.4s	remaining: 20m 54s
# 411:	total: 51.4s	remaining: 20m 51s
# 412:	total: 51.4s	remaining: 20m 48s
# 413:	total: 51.5s	remaining: 20m 45s
# 414:	total: 51.5s	remaining: 20m 42s
# 415:	learn: 1.2968260	test: 1.2991526	best: 1.2991526 (415)	total: 51.5s	remaining: 20m 39s
# 416:	total: 51.5s	remaining: 20m 37s
# 417:	total: 51.5s	remaining: 20m 34s
# 418:	total: 51.5s	remaining: 20m 31s
# 419:	total: 51.6s	remaining: 20m 28s
# 420:	learn: 1.2961505	test: 1.2985463	best: 1.2985463 (420)	total: 51.6s	remaining: 20m 25s
# 421:	total: 51.6s	remaining: 20m 23s
# 422:	total: 51.6s	remaining: 20m 20s
# 423:	total: 51.6s	remaining: 20m 17s
# 424:	total: 51.6s	remaining: 20m 15s
# 425:	learn: 1.2954129	test: 1.2979014	best: 1.2979014 (425)	total: 51.7s	remaining: 20m 12s
# 426:	total: 51.7s	remaining: 20m 9s
# 427:	total: 51.7s	remaining: 20m 7s
# 428:	total: 51.7s	remaining: 20m 4s
# 429:	total: 51.7s	remaining: 20m 1s
# 430:	learn: 1.2947704	test: 1.2973537	best: 1.2973537 (430)	total: 51.8s	remaining: 19m 59s
# 431:	total: 51.8s	remaining: 19m 56s
# 432:	total: 51.8s	remaining: 19m 54s
# 433:	total: 51.8s	remaining: 19m 51s
# 434:	total: 51.8s	remaining: 19m 48s
# 435:	learn: 1.2941233	test: 1.2968002	best: 1.2968002 (435)	total: 51.8s	remaining: 19m 46s
# 436:	total: 51.9s	remaining: 19m 43s
# 437:	total: 51.9s	remaining: 19m 41s
# 438:	total: 51.9s	remaining: 19m 38s
# 439:	total: 51.9s	remaining: 19m 36s
# 440:	learn: 1.2933994	test: 1.2961829	best: 1.2961829 (440)	total: 51.9s	remaining: 19m 33s
# 441:	total: 51.9s	remaining: 19m 31s
# 442:	total: 52s	remaining: 19m 28s
# 443:	total: 52s	remaining: 19m 25s
# 444:	total: 52s	remaining: 19m 23s
# 445:	learn: 1.2927818	test: 1.2956544	best: 1.2956544 (445)	total: 52s	remaining: 19m 21s
# 446:	total: 52s	remaining: 19m 18s
# 447:	total: 52s	remaining: 19m 16s
# 448:	total: 52.1s	remaining: 19m 13s
# 449:	total: 52.1s	remaining: 19m 11s
# 450:	learn: 1.2921763	test: 1.2951133	best: 1.2951133 (450)	total: 52.1s	remaining: 19m 8s
# 451:	total: 52.1s	remaining: 19m 6s
# 452:	total: 52.1s	remaining: 19m 4s
# 453:	total: 52.1s	remaining: 19m 1s
# 454:	total: 52.2s	remaining: 18m 59s
# 455:	learn: 1.2915780	test: 1.2946134	best: 1.2946134 (455)	total: 52.2s	remaining: 18m 56s
# 456:	total: 52.2s	remaining: 18m 54s
# 457:	total: 52.2s	remaining: 18m 52s
# 458:	total: 52.2s	remaining: 18m 49s
# 459:	total: 52.2s	remaining: 18m 47s
# 460:	learn: 1.2909816	test: 1.2940967	best: 1.2940967 (460)	total: 52.3s	remaining: 18m 45s
# 461:	total: 52.3s	remaining: 18m 42s
# 462:	total: 52.3s	remaining: 18m 40s
# 463:	total: 52.3s	remaining: 18m 38s
# 464:	total: 52.3s	remaining: 18m 36s
# 465:	learn: 1.2904515	test: 1.2936890	best: 1.2936890 (465)	total: 52.3s	remaining: 18m 33s
# 466:	total: 52.4s	remaining: 18m 31s
# 467:	total: 52.4s	remaining: 18m 29s
# 468:	total: 52.4s	remaining: 18m 27s
# 469:	total: 52.4s	remaining: 18m 24s
# 470:	learn: 1.2899162	test: 1.2932457	best: 1.2932457 (470)	total: 52.4s	remaining: 18m 22s
# 471:	total: 52.4s	remaining: 18m 20s
# 472:	total: 52.5s	remaining: 18m 18s
# 473:	total: 52.5s	remaining: 18m 16s
# 474:	total: 52.5s	remaining: 18m 14s
# 475:	learn: 1.2893322	test: 1.2927847	best: 1.2927847 (475)	total: 52.5s	remaining: 18m 11s
# 476:	total: 52.5s	remaining: 18m 9s
# 477:	total: 52.5s	remaining: 18m 7s
# 478:	total: 52.6s	remaining: 18m 5s
# 479:	total: 52.6s	remaining: 18m 3s
# 480:	learn: 1.2887626	test: 1.2923410	best: 1.2923410 (480)	total: 52.6s	remaining: 18m 1s
# 481:	total: 52.6s	remaining: 17m 59s
# 482:	total: 52.6s	remaining: 17m 57s
# 483:	total: 52.7s	remaining: 17m 55s
# 484:	total: 52.7s	remaining: 17m 53s
# 485:	learn: 1.2882134	test: 1.2918733	best: 1.2918733 (485)	total: 52.7s	remaining: 17m 51s
# 486:	total: 52.7s	remaining: 17m 49s
# 487:	total: 52.7s	remaining: 17m 47s
# 488:	total: 52.7s	remaining: 17m 45s
# 489:	total: 52.8s	remaining: 17m 43s
# 490:	learn: 1.2876802	test: 1.2914364	best: 1.2914364 (490)	total: 52.8s	remaining: 17m 41s
# 491:	total: 52.8s	remaining: 17m 39s
# 492:	total: 52.8s	remaining: 17m 37s
# 493:	total: 52.8s	remaining: 17m 35s
# 494:	total: 52.8s	remaining: 17m 33s
# 495:	learn: 1.2871257	test: 1.2909269	best: 1.2909269 (495)	total: 52.9s	remaining: 17m 31s
# 496:	total: 52.9s	remaining: 17m 29s
# 497:	total: 52.9s	remaining: 17m 27s
# 498:	total: 52.9s	remaining: 17m 25s
# 499:	total: 52.9s	remaining: 17m 23s
# 500:	learn: 1.2865494	test: 1.2904337	best: 1.2904337 (500)	total: 53s	remaining: 17m 21s
# 501:	total: 53s	remaining: 17m 19s
# 502:	total: 53s	remaining: 17m 17s
# 503:	total: 53s	remaining: 17m 15s
# 504:	total: 53s	remaining: 17m 13s
# 505:	learn: 1.2860126	test: 1.2900025	best: 1.2900025 (505)	total: 53s	remaining: 17m 11s
# 506:	total: 53.1s	remaining: 17m 10s
# 507:	total: 53.1s	remaining: 17m 8s
# 508:	total: 53.1s	remaining: 17m 6s
# 509:	total: 53.1s	remaining: 17m 4s
# 510:	learn: 1.2854745	test: 1.2895515	best: 1.2895515 (510)	total: 53.1s	remaining: 17m 2s
# 511:	total: 53.1s	remaining: 17m
# 512:	total: 53.2s	remaining: 16m 58s
# 513:	total: 53.2s	remaining: 16m 57s
# 514:	total: 53.2s	remaining: 16m 55s
# 515:	learn: 1.2849262	test: 1.2891000	best: 1.2891000 (515)	total: 53.2s	remaining: 16m 53s
# 516:	total: 53.2s	remaining: 16m 51s
# 517:	total: 53.3s	remaining: 16m 49s
# 518:	total: 53.3s	remaining: 16m 48s
# 519:	total: 53.3s	remaining: 16m 46s
# 520:	learn: 1.2844474	test: 1.2887266	best: 1.2887266 (520)	total: 53.3s	remaining: 16m 44s
# 521:	total: 53.3s	remaining: 16m 42s
# 522:	total: 53.3s	remaining: 16m 41s
# 523:	total: 53.4s	remaining: 16m 39s
# 524:	total: 53.4s	remaining: 16m 37s
# 525:	learn: 1.2839700	test: 1.2883640	best: 1.2883640 (525)	total: 53.4s	remaining: 16m 35s
# 526:	total: 53.4s	remaining: 16m 34s
# 527:	total: 53.4s	remaining: 16m 32s
# 528:	total: 53.4s	remaining: 16m 30s
# 529:	total: 53.5s	remaining: 16m 28s
# 530:	learn: 1.2835199	test: 1.2880153	best: 1.2880153 (530)	total: 53.5s	remaining: 16m 27s
# 531:	total: 53.5s	remaining: 16m 25s
# 532:	total: 53.5s	remaining: 16m 23s
# 533:	total: 53.5s	remaining: 16m 22s
# 534:	total: 53.6s	remaining: 16m 20s
# 535:	learn: 1.2830432	test: 1.2876370	best: 1.2876370 (535)	total: 53.6s	remaining: 16m 18s
# 536:	total: 53.6s	remaining: 16m 17s
# 537:	total: 53.6s	remaining: 16m 15s
# 538:	total: 53.6s	remaining: 16m 13s
# 539:	total: 53.6s	remaining: 16m 12s
# 540:	learn: 1.2825954	test: 1.2872663	best: 1.2872663 (540)	total: 53.7s	remaining: 16m 10s
# 541:	total: 53.7s	remaining: 16m 8s
# 542:	total: 53.7s	remaining: 16m 7s
# 543:	total: 53.7s	remaining: 16m 5s
# 544:	total: 53.7s	remaining: 16m 3s
# 545:	learn: 1.2821247	test: 1.2869272	best: 1.2869272 (545)	total: 53.7s	remaining: 16m 2s
# 546:	total: 53.8s	remaining: 16m
# 547:	total: 53.8s	remaining: 15m 59s
# 548:	total: 53.8s	remaining: 15m 57s
# 549:	total: 53.8s	remaining: 15m 55s
# 550:	learn: 1.2816758	test: 1.2865741	best: 1.2865741 (550)	total: 53.8s	remaining: 15m 54s
# 551:	total: 53.9s	remaining: 15m 52s
# 552:	total: 53.9s	remaining: 15m 51s
# 553:	total: 53.9s	remaining: 15m 49s
# 554:	total: 53.9s	remaining: 15m 48s
# 555:	learn: 1.2811950	test: 1.2861790	best: 1.2861790 (555)	total: 53.9s	remaining: 15m 46s
# 556:	total: 53.9s	remaining: 15m 46s
# 557:	total: 56.6s	remaining: 16m 30s
# 558:	total: 56.6s	remaining: 16m 29s
# 559:	total: 56.6s	remaining: 16m 27s
# 560:	learn: 1.2807355	test: 1.2857962	best: 1.2857962 (560)	total: 56.6s	remaining: 16m 25s
# 561:	total: 56.6s	remaining: 16m 24s
# 562:	total: 56.6s	remaining: 16m 22s
# 563:	total: 56.7s	remaining: 16m 20s
# 564:	total: 56.7s	remaining: 16m 19s
# 565:	learn: 1.2803089	test: 1.2854277	best: 1.2854277 (565)	total: 56.7s	remaining: 16m 17s
# 566:	total: 56.7s	remaining: 16m 16s
# 567:	total: 56.7s	remaining: 16m 14s
# 568:	total: 56.7s	remaining: 16m 12s
# 569:	total: 56.8s	remaining: 16m 11s
# 570:	learn: 1.2798761	test: 1.2851430	best: 1.2851430 (570)	total: 56.8s	remaining: 16m 9s
# 571:	total: 56.8s	remaining: 16m 8s
# 572:	total: 56.8s	remaining: 16m 6s
# 573:	total: 56.8s	remaining: 16m 5s
# 574:	total: 56.8s	remaining: 16m 3s
# 575:	learn: 1.2794148	test: 1.2847839	best: 1.2847839 (575)	total: 56.9s	remaining: 16m 2s
# 576:	total: 56.9s	remaining: 16m
# 577:	total: 56.9s	remaining: 15m 58s
# 578:	total: 56.9s	remaining: 15m 57s
# 579:	total: 56.9s	remaining: 15m 55s
# 580:	learn: 1.2790293	test: 1.2844434	best: 1.2844434 (580)	total: 56.9s	remaining: 15m 55s
# 581:	total: 59.6s	remaining: 16m 38s
# 582:	total: 59.6s	remaining: 16m 36s
# 583:	total: 59.6s	remaining: 16m 34s
# 584:	total: 59.6s	remaining: 16m 34s
# 585:	learn: 1.2786377	test: 1.2841462	best: 1.2841462 (585)	total: 59.6s	remaining: 16m 33s
# 586:	total: 1m 2s	remaining: 17m 14s
# 587:	total: 1m 2s	remaining: 17m 13s
# 588:	total: 1m 2s	remaining: 17m 11s
# 589:	total: 1m 2s	remaining: 17m 10s
# 590:	learn: 1.2782557	test: 1.2838472	best: 1.2838472 (590)	total: 1m 2s	remaining: 17m 8s
# 591:	total: 1m 2s	remaining: 17m 6s
# 592:	total: 1m 2s	remaining: 17m 5s
# 593:	total: 1m 2s	remaining: 17m 3s
# 594:	total: 1m 2s	remaining: 17m 1s
# 595:	learn: 1.2778901	test: 1.2835603	best: 1.2835603 (595)	total: 1m 2s	remaining: 17m
# 596:	total: 1m 2s	remaining: 16m 58s
# 597:	total: 1m 2s	remaining: 16m 57s
# 598:	total: 1m 2s	remaining: 16m 57s
# 599:	total: 1m 2s	remaining: 16m 55s
# 600:	learn: 1.2774389	test: 1.2831699	best: 1.2831699 (600)	total: 1m 2s	remaining: 16m 53s
# 601:	total: 1m 5s	remaining: 17m 34s
# 602:	total: 1m 5s	remaining: 17m 32s
# 603:	total: 1m 5s	remaining: 17m 31s
# 604:	total: 1m 5s	remaining: 17m 31s
# 605:	learn: 1.2769886	test: 1.2827976	best: 1.2827976 (605)	total: 1m 7s	remaining: 18m 11s
# 606:	total: 1m 7s	remaining: 18m 9s
# 607:	total: 1m 7s	remaining: 18m 7s
# 608:	total: 1m 7s	remaining: 18m 6s
# 609:	total: 1m 7s	remaining: 18m 4s
# 610:	learn: 1.2766394	test: 1.2825102	best: 1.2825102 (610)	total: 1m 7s	remaining: 18m 2s
# 611:	total: 1m 7s	remaining: 18m 1s
# 612:	total: 1m 7s	remaining: 17m 59s
# 613:	total: 1m 7s	remaining: 17m 57s
# 614:	total: 1m 7s	remaining: 17m 55s
# 615:	learn: 1.2762755	test: 1.2822249	best: 1.2822249 (615)	total: 1m 7s	remaining: 17m 54s
# 616:	total: 1m 7s	remaining: 17m 52s
# 617:	total: 1m 7s	remaining: 17m 50s
# 618:	total: 1m 7s	remaining: 17m 49s
# 619:	total: 1m 7s	remaining: 17m 47s
# 620:	learn: 1.2758916	test: 1.2819122	best: 1.2819122 (620)	total: 1m 7s	remaining: 17m 45s
# 621:	total: 1m 7s	remaining: 17m 44s
# 622:	total: 1m 7s	remaining: 17m 42s
# 623:	total: 1m 8s	remaining: 17m 40s
# 624:	total: 1m 8s	remaining: 17m 39s
# 625:	learn: 1.2755020	test: 1.2816360	best: 1.2816360 (625)	total: 1m 8s	remaining: 17m 37s
# 626:	total: 1m 8s	remaining: 17m 35s
# 627:	total: 1m 8s	remaining: 17m 34s
# 628:	total: 1m 8s	remaining: 17m 32s
# 629:	total: 1m 8s	remaining: 17m 31s
# 630:	learn: 1.2751374	test: 1.2813580	best: 1.2813580 (630)	total: 1m 8s	remaining: 17m 29s
# 631:	total: 1m 8s	remaining: 17m 27s
# 632:	total: 1m 8s	remaining: 17m 26s
# 633:	total: 1m 8s	remaining: 17m 26s
# 634:	total: 1m 8s	remaining: 17m 24s
# 635:	learn: 1.2747281	test: 1.2810405	best: 1.2810405 (635)	total: 1m 10s	remaining: 18m 2s
# 636:	total: 1m 10s	remaining: 18m 1s
# 637:	total: 1m 10s	remaining: 17m 59s
# 638:	total: 1m 10s	remaining: 17m 57s
# 639:	total: 1m 10s	remaining: 17m 56s
# 640:	learn: 1.2744029	test: 1.2807753	best: 1.2807753 (640)	total: 1m 10s	remaining: 17m 54s
# 641:	total: 1m 10s	remaining: 17m 52s
# 642:	total: 1m 10s	remaining: 17m 51s
# 643:	total: 1m 10s	remaining: 17m 49s
# 644:	total: 1m 10s	remaining: 17m 49s
# 645:	learn: 1.2740232	test: 1.2804233	best: 1.2804233 (645)	total: 1m 10s	remaining: 17m 48s
# 646:	total: 1m 10s	remaining: 17m 46s
# 647:	total: 1m 10s	remaining: 17m 44s
# 648:	total: 1m 10s	remaining: 17m 43s
# 649:	total: 1m 13s	remaining: 18m 20s
# 650:	learn: 1.2736002	test: 1.2800811	best: 1.2800811 (650)	total: 1m 13s	remaining: 18m 19s
# 651:	total: 1m 13s	remaining: 18m 17s
# 652:	total: 1m 13s	remaining: 18m 15s
# 653:	total: 1m 13s	remaining: 18m 15s
# 654:	total: 1m 16s	remaining: 18m 52s
# 655:	learn: 1.2732201	test: 1.2797536	best: 1.2797536 (655)	total: 1m 16s	remaining: 18m 51s
# 656:	total: 1m 16s	remaining: 18m 49s
# 657:	total: 1m 16s	remaining: 18m 47s
# 658:	total: 1m 16s	remaining: 18m 46s
# 659:	total: 1m 16s	remaining: 18m 44s
# 660:	learn: 1.2728830	test: 1.2794425	best: 1.2794425 (660)	total: 1m 16s	remaining: 18m 42s
# 661:	total: 1m 16s	remaining: 18m 41s
# 662:	total: 1m 16s	remaining: 18m 39s
# 663:	total: 1m 16s	remaining: 18m 37s
# 664:	total: 1m 16s	remaining: 18m 37s
# 665:	learn: 1.2724909	test: 1.2791283	best: 1.2791283 (665)	total: 1m 19s	remaining: 19m 14s
# 666:	total: 1m 19s	remaining: 19m 12s
# 667:	total: 1m 19s	remaining: 19m 10s
# 668:	total: 1m 19s	remaining: 19m 9s
# 669:	total: 1m 19s	remaining: 19m 9s
# 670:	learn: 1.2721310	test: 1.2788299	best: 1.2788299 (670)	total: 1m 19s	remaining: 19m 7s
# 671:	total: 1m 21s	remaining: 19m 43s
# 672:	total: 1m 21s	remaining: 19m 41s
# 673:	total: 1m 21s	remaining: 19m 39s
# 674:	total: 1m 21s	remaining: 19m 38s
# 675:	learn: 1.2717926	test: 1.2785536	best: 1.2785536 (675)	total: 1m 21s	remaining: 19m 36s
# 676:	total: 1m 21s	remaining: 19m 34s
# 677:	total: 1m 21s	remaining: 19m 32s
# 678:	total: 1m 21s	remaining: 19m 31s
# 679:	total: 1m 21s	remaining: 19m 29s
# 680:	learn: 1.2714946	test: 1.2782977	best: 1.2782977 (680)	total: 1m 21s	remaining: 19m 27s
# 681:	total: 1m 21s	remaining: 19m 26s
# 682:	total: 1m 21s	remaining: 19m 24s
# 683:	total: 1m 21s	remaining: 19m 24s
# 684:	total: 1m 21s	remaining: 19m 22s
# 685:	learn: 1.2711609	test: 1.2780140	best: 1.2780140 (685)	total: 1m 24s	remaining: 19m 57s
# 686:	total: 1m 24s	remaining: 19m 56s
# 687:	total: 1m 24s	remaining: 19m 54s
# 688:	total: 1m 24s	remaining: 19m 54s
# 689:	total: 1m 27s	remaining: 20m 29s
# 690:	learn: 1.2708147	test: 1.2777153	best: 1.2777153 (690)	total: 1m 27s	remaining: 20m 27s
# 691:	total: 1m 29s	remaining: 21m 2s
# 692:	total: 1m 29s	remaining: 21m 2s
# 693:	total: 1m 29s	remaining: 21m
# 694:	total: 1m 29s	remaining: 20m 58s
# 695:	learn: 1.2704713	test: 1.2774415	best: 1.2774415 (695)	total: 1m 29s	remaining: 20m 56s
# 696:	total: 1m 32s	remaining: 21m 31s
# 697:	total: 1m 32s	remaining: 21m 29s
# 698:	total: 1m 32s	remaining: 21m 27s
# 699:	total: 1m 32s	remaining: 21m 25s
# 700:	learn: 1.2701628	test: 1.2771706	best: 1.2771706 (700)	total: 1m 32s	remaining: 21m 24s
# 701:	total: 1m 32s	remaining: 21m 22s
# 702:	total: 1m 32s	remaining: 21m 20s
# 703:	total: 1m 32s	remaining: 21m 18s
# 704:	total: 1m 32s	remaining: 21m 16s
# 705:	learn: 1.2698711	test: 1.2769678	best: 1.2769678 (705)	total: 1m 32s	remaining: 21m 15s
# 706:	total: 1m 32s	remaining: 21m 13s
# 707:	total: 1m 32s	remaining: 21m 11s
# 708:	total: 1m 32s	remaining: 21m 9s
# 709:	total: 1m 32s	remaining: 21m 7s
# 710:	learn: 1.2695432	test: 1.2767076	best: 1.2767076 (710)	total: 1m 32s	remaining: 21m 6s
# 711:	total: 1m 32s	remaining: 21m 4s
# 712:	total: 1m 32s	remaining: 21m 2s
# 713:	total: 1m 32s	remaining: 21m
# 714:	total: 1m 32s	remaining: 20m 58s
# 715:	learn: 1.2692153	test: 1.2764164	best: 1.2764164 (715)	total: 1m 32s	remaining: 20m 57s
# 716:	total: 1m 32s	remaining: 20m 55s
# 717:	total: 1m 32s	remaining: 20m 53s
# 718:	total: 1m 32s	remaining: 20m 52s
# 719:	total: 1m 32s	remaining: 20m 50s
# 720:	learn: 1.2689452	test: 1.2762061	best: 1.2762061 (720)	total: 1m 32s	remaining: 20m 48s
# 721:	total: 1m 32s	remaining: 20m 46s
# 722:	total: 1m 32s	remaining: 20m 45s
# 723:	total: 1m 32s	remaining: 20m 43s
# 724:	total: 1m 32s	remaining: 20m 41s
# 725:	learn: 1.2686762	test: 1.2759972	best: 1.2759972 (725)	total: 1m 32s	remaining: 20m 39s
# 726:	total: 1m 32s	remaining: 20m 38s
# 727:	total: 1m 32s	remaining: 20m 36s
# 728:	total: 1m 32s	remaining: 20m 34s
# 729:	total: 1m 32s	remaining: 20m 33s
# 730:	learn: 1.2683599	test: 1.2757023	best: 1.2757023 (730)	total: 1m 32s	remaining: 20m 31s
# 731:	total: 1m 33s	remaining: 20m 29s
# 732:	total: 1m 33s	remaining: 20m 28s
# 733:	total: 1m 33s	remaining: 20m 26s
# 734:	total: 1m 33s	remaining: 20m 24s
# 735:	learn: 1.2680795	test: 1.2754626	best: 1.2754626 (735)	total: 1m 33s	remaining: 20m 22s
# 736:	total: 1m 33s	remaining: 20m 21s
# 737:	total: 1m 33s	remaining: 20m 19s
# 738:	total: 1m 33s	remaining: 20m 19s
# 739:	total: 1m 33s	remaining: 20m 17s
# 740:	learn: 1.2677379	test: 1.2751607	best: 1.2751607 (740)	total: 1m 33s	remaining: 20m 16s
# 741:	total: 1m 35s	remaining: 20m 48s
# 742:	total: 1m 35s	remaining: 20m 46s
# 743:	total: 1m 35s	remaining: 20m 45s
# 744:	total: 1m 35s	remaining: 20m 43s
# 745:	learn: 1.2673994	test: 1.2748576	best: 1.2748576 (745)	total: 1m 35s	remaining: 20m 41s
# 746:	total: 1m 35s	remaining: 20m 40s
# 747:	total: 1m 35s	remaining: 20m 38s
# 748:	total: 1m 35s	remaining: 20m 36s
# 749:	total: 1m 35s	remaining: 20m 35s
# 750:	learn: 1.2670886	test: 1.2746110	best: 1.2746110 (750)	total: 1m 35s	remaining: 20m 33s
# 751:	total: 1m 35s	remaining: 20m 31s
# 752:	total: 1m 35s	remaining: 20m 30s
# 753:	total: 1m 35s	remaining: 20m 30s
# 754:	total: 1m 38s	remaining: 21m 1s
# 755:	learn: 1.2668008	test: 1.2743546	best: 1.2743546 (755)	total: 1m 38s	remaining: 21m
# 756:	total: 1m 38s	remaining: 21m
# 757:	total: 1m 41s	remaining: 21m 31s
# 758:	total: 1m 41s	remaining: 21m 29s
# 759:	total: 1m 41s	remaining: 21m 28s
# 760:	learn: 1.2664637	test: 1.2740525	best: 1.2740525 (760)	total: 1m 41s	remaining: 21m 26s
# 761:	total: 1m 41s	remaining: 21m 24s
# 762:	total: 1m 41s	remaining: 21m 23s
# 763:	total: 1m 41s	remaining: 21m 21s
# 764:	total: 1m 41s	remaining: 21m 19s
# 765:	learn: 1.2662081	test: 1.2738408	best: 1.2738408 (765)	total: 1m 41s	remaining: 21m 17s
# 766:	total: 1m 41s	remaining: 21m 16s
# 767:	total: 1m 41s	remaining: 21m 14s
# 768:	total: 1m 41s	remaining: 21m 12s
# 769:	total: 1m 41s	remaining: 21m 11s
# 770:	learn: 1.2659273	test: 1.2736332	best: 1.2736332 (770)	total: 1m 41s	remaining: 21m 9s
# 771:	total: 1m 41s	remaining: 21m 7s
# 772:	total: 1m 41s	remaining: 21m 6s
# 773:	total: 1m 41s	remaining: 21m 4s
# 774:	total: 1m 41s	remaining: 21m 2s
# 775:	learn: 1.2656136	test: 1.2733764	best: 1.2733764 (775)	total: 1m 41s	remaining: 21m 1s
# 776:	total: 1m 41s	remaining: 20m 59s
# 777:	total: 1m 41s	remaining: 20m 58s
# 778:	total: 1m 41s	remaining: 20m 56s
# 779:	total: 1m 41s	remaining: 20m 54s
# 780:	learn: 1.2653265	test: 1.2731307	best: 1.2731307 (780)	total: 1m 41s	remaining: 20m 53s
# 781:	total: 1m 41s	remaining: 20m 51s
# 782:	total: 1m 41s	remaining: 20m 49s
# 783:	total: 1m 41s	remaining: 20m 48s
# 784:	total: 1m 41s	remaining: 20m 46s
# 785:	learn: 1.2650465	test: 1.2728869	best: 1.2728869 (785)	total: 1m 41s	remaining: 20m 45s
# 786:	total: 1m 41s	remaining: 20m 43s
# 787:	total: 1m 41s	remaining: 20m 41s
# 788:	total: 1m 41s	remaining: 20m 40s
# 789:	total: 1m 41s	remaining: 20m 38s
# 790:	learn: 1.2647755	test: 1.2726636	best: 1.2726636 (790)	total: 1m 41s	remaining: 20m 37s
# 791:	total: 1m 41s	remaining: 20m 35s
# 792:	total: 1m 41s	remaining: 20m 33s
# 793:	total: 1m 41s	remaining: 20m 32s
# 794:	total: 1m 41s	remaining: 20m 30s
# 795:	learn: 1.2644679	test: 1.2724106	best: 1.2724106 (795)	total: 1m 41s	remaining: 20m 29s
# 796:	total: 1m 41s	remaining: 20m 27s
# 797:	total: 1m 41s	remaining: 20m 26s
# 798:	total: 1m 41s	remaining: 20m 24s
# 799:	total: 1m 41s	remaining: 20m 22s
# 800:	learn: 1.2642175	test: 1.2721861	best: 1.2721861 (800)	total: 1m 41s	remaining: 20m 21s
# 801:	total: 1m 41s	remaining: 20m 19s
# 802:	total: 1m 41s	remaining: 20m 18s
# 803:	total: 1m 41s	remaining: 20m 16s
# 804:	total: 1m 41s	remaining: 20m 15s
# 805:	learn: 1.2639704	test: 1.2719325	best: 1.2719325 (805)	total: 1m 41s	remaining: 20m 13s
# 806:	total: 1m 41s	remaining: 20m 12s
# 807:	total: 1m 41s	remaining: 20m 10s
# 808:	total: 1m 41s	remaining: 20m 10s
# 809:	total: 1m 44s	remaining: 20m 40s
# 810:	learn: 1.2637123	test: 1.2717109	best: 1.2717109 (810)	total: 1m 44s	remaining: 20m 38s
# 811:	total: 1m 44s	remaining: 20m 36s
# 812:	total: 1m 44s	remaining: 20m 35s
# 813:	total: 1m 44s	remaining: 20m 33s
# 814:	total: 1m 44s	remaining: 20m 32s
# 815:	learn: 1.2634362	test: 1.2714773	best: 1.2714773 (815)	total: 1m 44s	remaining: 20m 30s
# 816:	total: 1m 44s	remaining: 20m 29s
# 817:	total: 1m 44s	remaining: 20m 27s
# 818:	total: 1m 44s	remaining: 20m 26s
# 819:	total: 1m 44s	remaining: 20m 24s
# 820:	learn: 1.2632058	test: 1.2712845	best: 1.2712845 (820)	total: 1m 44s	remaining: 20m 23s
# 821:	total: 1m 44s	remaining: 20m 21s
# 822:	total: 1m 44s	remaining: 20m 20s
# 823:	total: 1m 44s	remaining: 20m 18s
# 824:	total: 1m 44s	remaining: 20m 17s
# 825:	learn: 1.2629544	test: 1.2710664	best: 1.2710664 (825)	total: 1m 44s	remaining: 20m 15s
# 826:	total: 1m 44s	remaining: 20m 14s
# 827:	total: 1m 44s	remaining: 20m 12s
# 828:	total: 1m 44s	remaining: 20m 11s
# 829:	total: 1m 44s	remaining: 20m 9s
# 830:	learn: 1.2627137	test: 1.2708765	best: 1.2708765 (830)	total: 1m 44s	remaining: 20m 8s
# 831:	total: 1m 44s	remaining: 20m 6s
# 832:	total: 1m 44s	remaining: 20m 5s
# 833:	total: 1m 44s	remaining: 20m 3s
# 834:	total: 1m 44s	remaining: 20m 2s
# 835:	learn: 1.2624707	test: 1.2706713	best: 1.2706713 (835)	total: 1m 44s	remaining: 20m
# 836:	total: 1m 44s	remaining: 19m 59s
# 837:	total: 1m 45s	remaining: 19m 58s
# 838:	total: 1m 45s	remaining: 19m 56s
# 839:	total: 1m 45s	remaining: 19m 55s
# 840:	learn: 1.2622217	test: 1.2704788	best: 1.2704788 (840)	total: 1m 45s	remaining: 19m 53s
# 841:	total: 1m 45s	remaining: 19m 52s
# 842:	total: 1m 45s	remaining: 19m 50s
# 843:	total: 1m 45s	remaining: 19m 49s
# 844:	total: 1m 45s	remaining: 19m 47s
# 845:	learn: 1.2619784	test: 1.2702762	best: 1.2702762 (845)	total: 1m 45s	remaining: 19m 46s
# 846:	total: 1m 45s	remaining: 19m 45s
# 847:	total: 1m 45s	remaining: 19m 43s
# 848:	total: 1m 45s	remaining: 19m 42s
# 849:	total: 1m 45s	remaining: 19m 40s
# 850:	learn: 1.2617503	test: 1.2701183	best: 1.2701183 (850)	total: 1m 45s	remaining: 19m 39s
# 851:	total: 1m 45s	remaining: 19m 38s
# 852:	total: 1m 45s	remaining: 19m 36s
# 853:	total: 1m 45s	remaining: 19m 35s
# 854:	total: 1m 45s	remaining: 19m 33s
# 855:	learn: 1.2614989	test: 1.2698859	best: 1.2698859 (855)	total: 1m 45s	remaining: 19m 32s
# 856:	total: 1m 45s	remaining: 19m 31s
# 857:	total: 1m 45s	remaining: 19m 29s
# 858:	total: 1m 45s	remaining: 19m 28s
# 859:	total: 1m 45s	remaining: 19m 26s
# 860:	learn: 1.2612596	test: 1.2696922	best: 1.2696922 (860)	total: 1m 45s	remaining: 19m 25s
# 861:	total: 1m 45s	remaining: 19m 24s
# 862:	total: 1m 45s	remaining: 19m 22s
# 863:	total: 1m 45s	remaining: 19m 21s
# 864:	total: 1m 45s	remaining: 19m 20s
# 865:	learn: 1.2609874	test: 1.2694665	best: 1.2694665 (865)	total: 1m 45s	remaining: 19m 18s
# 866:	total: 1m 45s	remaining: 19m 17s
# 867:	total: 1m 45s	remaining: 19m 16s
# 868:	total: 1m 45s	remaining: 19m 14s
# 869:	total: 1m 45s	remaining: 19m 13s
# 870:	learn: 1.2607363	test: 1.2692644	best: 1.2692644 (870)	total: 1m 45s	remaining: 19m 12s
# 871:	total: 1m 45s	remaining: 19m 10s
# 872:	total: 1m 45s	remaining: 19m 9s
# 873:	total: 1m 45s	remaining: 19m 8s
# 874:	total: 1m 45s	remaining: 19m 6s
# 875:	learn: 1.2605098	test: 1.2690790	best: 1.2690790 (875)	total: 1m 45s	remaining: 19m 5s
# 876:	total: 1m 45s	remaining: 19m 4s
# 877:	total: 1m 45s	remaining: 19m 2s
# 878:	total: 1m 45s	remaining: 19m 1s
# 879:	total: 1m 45s	remaining: 19m
# 880:	learn: 1.2602623	test: 1.2688814	best: 1.2688814 (880)	total: 1m 45s	remaining: 18m 58s
# 881:	total: 1m 45s	remaining: 18m 57s
# 882:	total: 1m 45s	remaining: 18m 56s
# 883:	total: 1m 45s	remaining: 18m 54s
# 884:	total: 1m 45s	remaining: 18m 53s
# 885:	learn: 1.2600297	test: 1.2686908	best: 1.2686908 (885)	total: 1m 45s	remaining: 18m 52s
# 886:	total: 1m 45s	remaining: 18m 51s
# 887:	total: 1m 45s	remaining: 18m 49s
# 888:	total: 1m 45s	remaining: 18m 48s
# 889:	total: 1m 45s	remaining: 18m 47s
# 890:	learn: 1.2598220	test: 1.2685335	best: 1.2685335 (890)	total: 1m 45s	remaining: 18m 45s
# 891:	total: 1m 45s	remaining: 18m 44s
# 892:	total: 1m 45s	remaining: 18m 43s
# 893:	total: 1m 45s	remaining: 18m 41s
# 894:	total: 1m 45s	remaining: 18m 40s
# 895:	learn: 1.2596161	test: 1.2683608	best: 1.2683608 (895)	total: 1m 45s	remaining: 18m 39s
# 896:	total: 1m 45s	remaining: 18m 38s
# 897:	total: 1m 45s	remaining: 18m 38s
# 898:	total: 1m 48s	remaining: 19m 4s
# 899:	total: 1m 48s	remaining: 19m 2s
# 900:	learn: 1.2593887	test: 1.2681795	best: 1.2681795 (900)	total: 1m 48s	remaining: 19m 2s
# 901:	total: 1m 51s	remaining: 19m 28s
# 902:	total: 1m 51s	remaining: 19m 27s
# 903:	total: 1m 51s	remaining: 19m 27s
# 904:	total: 1m 51s	remaining: 19m 26s
# 905:	learn: 1.2591959	test: 1.2680241	best: 1.2680241 (905)	total: 1m 53s	remaining: 19m 52s
# 906:	total: 1m 53s	remaining: 19m 50s
# 907:	total: 1m 53s	remaining: 19m 49s
# 908:	total: 1m 53s	remaining: 19m 48s
# 909:	total: 1m 53s	remaining: 19m 46s
# 910:	learn: 1.2589646	test: 1.2678198	best: 1.2678198 (910)	total: 1m 53s	remaining: 19m 45s
# 911:	total: 1m 53s	remaining: 19m 44s
# 912:	total: 1m 53s	remaining: 19m 42s
# 913:	total: 1m 53s	remaining: 19m 41s
# 914:	total: 1m 53s	remaining: 19m 40s
# 915:	learn: 1.2587447	test: 1.2676416	best: 1.2676416 (915)	total: 1m 53s	remaining: 19m 38s
# 916:	total: 1m 53s	remaining: 19m 37s
# 917:	total: 1m 53s	remaining: 19m 36s
# 918:	total: 1m 53s	remaining: 19m 34s
# 919:	total: 1m 54s	remaining: 19m 33s
# 920:	learn: 1.2585279	test: 1.2674856	best: 1.2674856 (920)	total: 1m 54s	remaining: 19m 32s
# 921:	total: 1m 54s	remaining: 19m 31s
# 922:	total: 1m 54s	remaining: 19m 29s
# 923:	total: 1m 54s	remaining: 19m 28s
# 924:	total: 1m 54s	remaining: 19m 27s
# 925:	learn: 1.2583101	test: 1.2673079	best: 1.2673079 (925)	total: 1m 54s	remaining: 19m 25s
# 926:	total: 1m 54s	remaining: 19m 24s
# 927:	total: 1m 54s	remaining: 19m 23s
# 928:	total: 1m 54s	remaining: 19m 22s
# 929:	total: 1m 54s	remaining: 19m 20s
# 930:	learn: 1.2581193	test: 1.2671318	best: 1.2671318 (930)	total: 1m 54s	remaining: 19m 19s
# 931:	total: 1m 54s	remaining: 19m 18s
# 932:	total: 1m 54s	remaining: 19m 17s
# 933:	total: 1m 54s	remaining: 19m 17s
# 934:	total: 1m 56s	remaining: 19m 41s
# 935:	learn: 1.2579040	test: 1.2669710	best: 1.2669710 (935)	total: 1m 56s	remaining: 19m 40s
# 936:	total: 1m 56s	remaining: 19m 39s
# 937:	total: 1m 56s	remaining: 19m 38s
# 938:	total: 1m 56s	remaining: 19m 36s
# 939:	total: 1m 56s	remaining: 19m 35s
# 940:	learn: 1.2576620	test: 1.2667840	best: 1.2667840 (940)	total: 1m 56s	remaining: 19m 34s
# 941:	total: 1m 56s	remaining: 19m 32s
# 942:	total: 1m 56s	remaining: 19m 31s
# 943:	total: 1m 56s	remaining: 19m 30s
# 944:	total: 1m 56s	remaining: 19m 29s
# 945:	learn: 1.2574350	test: 1.2665891	best: 1.2665891 (945)	total: 1m 57s	remaining: 19m 27s
# 946:	total: 1m 57s	remaining: 19m 26s
# 947:	total: 1m 57s	remaining: 19m 25s
# 948:	total: 1m 57s	remaining: 19m 24s
# 949:	total: 1m 57s	remaining: 19m 22s
# 950:	learn: 1.2572533	test: 1.2664516	best: 1.2664516 (950)	total: 1m 57s	remaining: 19m 21s
# 951:	total: 1m 57s	remaining: 19m 20s
# 952:	total: 1m 57s	remaining: 19m 19s
# 953:	total: 1m 57s	remaining: 19m 17s
# 954:	total: 1m 57s	remaining: 19m 16s
# 955:	learn: 1.2570658	test: 1.2663457	best: 1.2663457 (955)	total: 1m 57s	remaining: 19m 15s
# 956:	total: 1m 57s	remaining: 19m 14s
# 957:	total: 1m 57s	remaining: 19m 12s
# 958:	total: 1m 57s	remaining: 19m 11s
# 959:	total: 1m 57s	remaining: 19m 10s
# 960:	learn: 1.2568686	test: 1.2662028	best: 1.2662028 (960)	total: 1m 57s	remaining: 19m 9s
# 961:	total: 1m 57s	remaining: 19m 8s
# 962:	total: 1m 57s	remaining: 19m 6s
# 963:	total: 1m 57s	remaining: 19m 5s
# 964:	total: 1m 57s	remaining: 19m 4s
# 965:	learn: 1.2566862	test: 1.2660862	best: 1.2660862 (965)	total: 1m 57s	remaining: 19m 3s
# 966:	total: 1m 57s	remaining: 19m 1s
# 967:	total: 1m 57s	remaining: 19m
# 968:	total: 1m 57s	remaining: 18m 59s
# 969:	total: 1m 57s	remaining: 18m 58s
# 970:	learn: 1.2564967	test: 1.2659205	best: 1.2659205 (970)	total: 1m 57s	remaining: 18m 57s
# 971:	total: 1m 57s	remaining: 18m 55s
# 972:	total: 1m 57s	remaining: 18m 54s
# 973:	total: 1m 57s	remaining: 18m 53s
# 974:	total: 1m 57s	remaining: 18m 52s
# 975:	learn: 1.2562716	test: 1.2657373	best: 1.2657373 (975)	total: 1m 57s	remaining: 18m 51s
# 976:	total: 1m 57s	remaining: 18m 49s
# 977:	total: 1m 57s	remaining: 18m 48s
# 978:	total: 1m 57s	remaining: 18m 47s
# 979:	total: 1m 57s	remaining: 18m 46s
# 980:	learn: 1.2560596	test: 1.2655802	best: 1.2655802 (980)	total: 1m 57s	remaining: 18m 45s
# 981:	total: 1m 57s	remaining: 18m 44s
# 982:	total: 1m 57s	remaining: 18m 42s
# 983:	total: 1m 57s	remaining: 18m 41s
# 984:	total: 1m 57s	remaining: 18m 40s
# 985:	learn: 1.2558530	test: 1.2654110	best: 1.2654110 (985)	total: 1m 57s	remaining: 18m 39s
# 986:	total: 1m 57s	remaining: 18m 38s
# 987:	total: 1m 57s	remaining: 18m 37s
# 988:	total: 1m 57s	remaining: 18m 36s
# 989:	total: 1m 57s	remaining: 18m 34s
# 990:	learn: 1.2556701	test: 1.2652582	best: 1.2652582 (990)	total: 1m 57s	remaining: 18m 33s
# 991:	total: 1m 57s	remaining: 18m 32s
# 992:	total: 1m 57s	remaining: 18m 31s
# 993:	total: 1m 57s	remaining: 18m 30s
# 994:	total: 1m 57s	remaining: 18m 29s
# 995:	learn: 1.2554717	test: 1.2651212	best: 1.2651212 (995)	total: 1m 57s	remaining: 18m 28s
# 996:	total: 1m 57s	remaining: 18m 26s
# 997:	total: 1m 57s	remaining: 18m 25s
# 998:	total: 1m 57s	remaining: 18m 24s
# ...
# 9671:	total: 2m 12s	remaining: 4.81s
# 9672:	total: 2m 12s	remaining: 4.79s
# 9673:	total: 2m 12s	remaining: 4.78s
# 9674:	total: 2m 12s	remaining: 4.76s
# 9675:	learn: 1.1300833	test: 1.2240982	best: 1.2240982 (9675)	total: 2m 12s	remaining: 4.75s
# 9676:	total: 2m 12s	remaining: 4.74s
# 9677:	total: 2m 12s	remaining: 4.72s
# 9678:	total: 2m 12s	remaining: 4.71s
# 9679:	total: 2m 12s	remaining: 4.69s
# 9680:	learn: 1.1300384	test: 1.2240929	best: 1.2240864 (9678)	total: 2m 12s	remaining: 4.68s
# 9681:	total: 2m 12s	remaining: 4.66s
# 9682:	total: 2m 12s	remaining: 4.65s
# 9683:	total: 2m 12s	remaining: 4.63s
# 9684:	total: 2m 12s	remaining: 4.62s
# 9685:	learn: 1.1299949	test: 1.2240946	best: 1.2240864 (9678)	total: 2m 12s	remaining: 4.6s
# 9686:	total: 2m 12s	remaining: 4.59s
# 9687:	total: 2m 12s	remaining: 4.57s
# 9688:	total: 2m 12s	remaining: 4.56s
# 9689:	total: 2m 12s	remaining: 4.54s
# 9690:	learn: 1.1299348	test: 1.2240834	best: 1.2240834 (9690)	total: 2m 12s	remaining: 4.53s
# 9691:	total: 2m 12s	remaining: 4.51s
# 9692:	total: 2m 12s	remaining: 4.5s
# 9693:	total: 2m 12s	remaining: 4.49s
# 9694:	total: 2m 12s	remaining: 4.47s
# 9695:	learn: 1.1298870	test: 1.2240695	best: 1.2240695 (9695)	total: 2m 12s	remaining: 4.46s
# 9696:	total: 2m 12s	remaining: 4.44s
# 9697:	total: 2m 12s	remaining: 4.43s
# 9698:	total: 2m 12s	remaining: 4.41s
# 9699:	total: 2m 12s	remaining: 4.4s
# 9700:	learn: 1.1298384	test: 1.2240561	best: 1.2240554 (9699)	total: 2m 12s	remaining: 4.38s
# 9701:	total: 2m 12s	remaining: 4.37s
# 9702:	total: 2m 12s	remaining: 4.35s
# 9703:	total: 2m 13s	remaining: 4.34s
# 9704:	total: 2m 13s	remaining: 4.32s
# 9705:	learn: 1.1297896	test: 1.2240434	best: 1.2240434 (9705)	total: 2m 13s	remaining: 4.31s
# 9706:	total: 2m 13s	remaining: 4.29s
# 9707:	total: 2m 13s	remaining: 4.28s
# 9708:	total: 2m 13s	remaining: 4.27s
# 9709:	total: 2m 13s	remaining: 4.25s
# 9710:	learn: 1.1297427	test: 1.2240479	best: 1.2240402 (9707)	total: 2m 13s	remaining: 4.24s
# 9711:	total: 2m 13s	remaining: 4.22s
# 9712:	total: 2m 13s	remaining: 4.21s
# 9713:	total: 2m 13s	remaining: 4.19s
# 9714:	total: 2m 13s	remaining: 4.18s
# 9715:	learn: 1.1296886	test: 1.2240314	best: 1.2240314 (9715)	total: 2m 13s	remaining: 4.16s
# 9716:	total: 2m 13s	remaining: 4.15s
# 9717:	total: 2m 13s	remaining: 4.13s
# 9718:	total: 2m 13s	remaining: 4.12s
# 9719:	total: 2m 13s	remaining: 4.1s
# 9720:	learn: 1.1296365	test: 1.2240229	best: 1.2240229 (9720)	total: 2m 13s	remaining: 4.09s
# 9721:	total: 2m 13s	remaining: 4.08s
# 9722:	total: 2m 13s	remaining: 4.06s
# 9723:	total: 2m 13s	remaining: 4.05s
# 9724:	total: 2m 13s	remaining: 4.03s
# 9725:	learn: 1.1295898	test: 1.2240144	best: 1.2240144 (9725)	total: 2m 13s	remaining: 4.02s
# 9726:	total: 2m 13s	remaining: 4s
# 9727:	total: 2m 13s	remaining: 3.99s
# 9728:	total: 2m 13s	remaining: 3.97s
# 9729:	total: 2m 13s	remaining: 3.96s
# 9730:	learn: 1.1295417	test: 1.2240124	best: 1.2240124 (9730)	total: 2m 13s	remaining: 3.94s
# 9731:	total: 2m 13s	remaining: 3.93s
# 9732:	total: 2m 13s	remaining: 3.92s
# 9733:	total: 2m 13s	remaining: 3.92s
# 9734:	total: 2m 13s	remaining: 3.92s
# 9735:	learn: 1.1294962	test: 1.2240160	best: 1.2240124 (9730)	total: 2m 13s	remaining: 3.87s
# 9736:	total: 2m 13s	remaining: 3.86s
# 9737:	total: 2m 13s	remaining: 3.86s
# 9738:	total: 2m 13s	remaining: 3.86s
# 9739:	total: 2m 13s	remaining: 3.81s
# 9740:	learn: 1.1294367	test: 1.2240193	best: 1.2240119 (9736)	total: 2m 13s	remaining: 3.8s
# 9741:	total: 2m 13s	remaining: 3.78s
# 9742:	total: 2m 13s	remaining: 3.77s
# 9743:	total: 2m 13s	remaining: 3.75s
# 9744:	total: 2m 13s	remaining: 3.74s
# 9745:	learn: 1.1293753	test: 1.2240162	best: 1.2240119 (9736)	total: 2m 13s	remaining: 3.73s
# 9746:	total: 2m 13s	remaining: 3.71s
# 9747:	total: 2m 13s	remaining: 3.7s
# 9748:	total: 2m 13s	remaining: 3.68s
# 9749:	total: 2m 13s	remaining: 3.67s
# 9750:	learn: 1.1293327	test: 1.2240170	best: 1.2240119 (9736)	total: 2m 13s	remaining: 3.65s
# 9751:	total: 2m 13s	remaining: 3.64s
# 9752:	total: 2m 13s	remaining: 3.63s
# 9753:	total: 2m 13s	remaining: 3.61s
# 9754:	total: 2m 13s	remaining: 3.6s
# 9755:	learn: 1.1292865	test: 1.2239986	best: 1.2239967 (9754)	total: 2m 13s	remaining: 3.58s
# 9756:	total: 2m 13s	remaining: 3.57s
# 9757:	total: 2m 13s	remaining: 3.55s
# 9758:	total: 2m 13s	remaining: 3.54s
# 9759:	total: 2m 13s	remaining: 3.52s
# 9760:	learn: 1.1292369	test: 1.2240031	best: 1.2239967 (9754)	total: 2m 13s	remaining: 3.51s
# 9761:	total: 2m 13s	remaining: 3.49s
# 9762:	total: 2m 14s	remaining: 3.48s
# 9763:	total: 2m 14s	remaining: 3.46s
# 9764:	total: 2m 14s	remaining: 3.45s
# 9765:	learn: 1.1291944	test: 1.2240031	best: 1.2239967 (9754)	total: 2m 14s	remaining: 3.44s
# 9766:	total: 2m 14s	remaining: 3.42s
# 9767:	total: 2m 14s	remaining: 3.41s
# 9768:	total: 2m 14s	remaining: 3.39s
# 9769:	total: 2m 14s	remaining: 3.38s
# 9770:	learn: 1.1291509	test: 1.2240017	best: 1.2239967 (9754)	total: 2m 14s	remaining: 3.36s
# 9771:	total: 2m 14s	remaining: 3.35s
# 9772:	total: 2m 14s	remaining: 3.33s
# 9773:	total: 2m 14s	remaining: 3.32s
# 9774:	total: 2m 14s	remaining: 3.3s
# 9775:	learn: 1.1291067	test: 1.2239969	best: 1.2239967 (9754)	total: 2m 14s	remaining: 3.29s
# 9776:	total: 2m 14s	remaining: 3.27s
# 9777:	total: 2m 14s	remaining: 3.26s
# 9778:	total: 2m 14s	remaining: 3.25s
# 9779:	total: 2m 14s	remaining: 3.23s
# 9780:	learn: 1.1290561	test: 1.2239847	best: 1.2239847 (9780)	total: 2m 14s	remaining: 3.22s
# 9781:	total: 2m 14s	remaining: 3.2s
# 9782:	total: 2m 14s	remaining: 3.19s
# 9783:	total: 2m 14s	remaining: 3.17s
# 9784:	total: 2m 14s	remaining: 3.16s
# 9785:	learn: 1.1290133	test: 1.2239866	best: 1.2239782 (9782)	total: 2m 14s	remaining: 3.14s
# 9786:	total: 2m 14s	remaining: 3.14s
# 9787:	total: 2m 14s	remaining: 3.14s
# 9788:	total: 2m 14s	remaining: 3.1s
# 9789:	total: 2m 14s	remaining: 3.08s
# 9790:	learn: 1.1289715	test: 1.2239745	best: 1.2239734 (9788)	total: 2m 14s	remaining: 3.07s
# 9791:	total: 2m 14s	remaining: 3.06s
# 9792:	total: 2m 14s	remaining: 3.04s
# 9793:	total: 2m 14s	remaining: 3.02s
# 9794:	total: 2m 14s	remaining: 3.01s
# 9795:	learn: 1.1289271	test: 1.2239628	best: 1.2239628 (9795)	total: 2m 14s	remaining: 3s
# 9796:	total: 2m 14s	remaining: 2.98s
# 9797:	total: 2m 14s	remaining: 2.97s
# 9798:	total: 2m 14s	remaining: 2.95s
# 9799:	total: 2m 14s	remaining: 2.94s
# 9800:	learn: 1.1288785	test: 1.2239496	best: 1.2239496 (9800)	total: 2m 14s	remaining: 2.92s
# 9801:	total: 2m 14s	remaining: 2.91s
# 9802:	total: 2m 14s	remaining: 2.89s
# 9803:	total: 2m 14s	remaining: 2.88s
# 9804:	total: 2m 14s	remaining: 2.86s
# 9805:	learn: 1.1288308	test: 1.2239425	best: 1.2239425 (9805)	total: 2m 14s	remaining: 2.85s
# 9806:	total: 2m 14s	remaining: 2.83s
# 9807:	total: 2m 14s	remaining: 2.82s
# 9808:	total: 2m 14s	remaining: 2.81s
# 9809:	total: 2m 14s	remaining: 2.79s
# 9810:	learn: 1.1287806	test: 1.2239482	best: 1.2239392 (9808)	total: 2m 14s	remaining: 2.78s
# 9811:	total: 2m 14s	remaining: 2.76s
# 9812:	total: 2m 14s	remaining: 2.75s
# 9813:	total: 2m 14s	remaining: 2.73s
# 9814:	total: 2m 14s	remaining: 2.72s
# 9815:	learn: 1.1287364	test: 1.2239364	best: 1.2239364 (9815)	total: 2m 14s	remaining: 2.7s
# 9816:	total: 2m 14s	remaining: 2.69s
# 9817:	total: 2m 14s	remaining: 2.67s
# 9818:	total: 2m 14s	remaining: 2.66s
# 9819:	total: 2m 14s	remaining: 2.65s
# 9820:	learn: 1.1286883	test: 1.2239390	best: 1.2239354 (9818)	total: 2m 14s	remaining: 2.63s
# 9821:	total: 2m 14s	remaining: 2.62s
# 9822:	total: 2m 15s	remaining: 2.6s
# 9823:	total: 2m 15s	remaining: 2.59s
# 9824:	total: 2m 15s	remaining: 2.57s
# 9825:	learn: 1.1286471	test: 1.2239326	best: 1.2239322 (9824)	total: 2m 15s	remaining: 2.56s
# 9826:	total: 2m 15s	remaining: 2.56s
# 9827:	total: 2m 15s	remaining: 2.56s
# 9828:	total: 2m 15s	remaining: 2.51s
# 9829:	total: 2m 15s	remaining: 2.5s
# 9830:	learn: 1.1285972	test: 1.2239252	best: 1.2239234 (9829)	total: 2m 15s	remaining: 2.48s
# 9831:	total: 2m 15s	remaining: 2.47s
# 9832:	total: 2m 15s	remaining: 2.45s
# 9833:	total: 2m 15s	remaining: 2.44s
# 9834:	total: 2m 15s	remaining: 2.42s
# 9835:	learn: 1.1285565	test: 1.2239142	best: 1.2239142 (9835)	total: 2m 15s	remaining: 2.41s
# 9836:	total: 2m 15s	remaining: 2.4s
# 9837:	total: 2m 15s	remaining: 2.38s
# 9838:	total: 2m 15s	remaining: 2.37s
# 9839:	total: 2m 15s	remaining: 2.35s
# 9840:	learn: 1.1285172	test: 1.2239139	best: 1.2239102 (9836)	total: 2m 15s	remaining: 2.34s
# 9841:	total: 2m 15s	remaining: 2.32s
# 9842:	total: 2m 15s	remaining: 2.31s
# 9843:	total: 2m 15s	remaining: 2.29s
# 9844:	total: 2m 15s	remaining: 2.28s
# 9845:	learn: 1.1284618	test: 1.2239069	best: 1.2239069 (9845)	total: 2m 15s	remaining: 2.26s
# 9846:	total: 2m 15s	remaining: 2.25s
# 9847:	total: 2m 15s	remaining: 2.23s
# 9848:	total: 2m 15s	remaining: 2.22s
# 9849:	total: 2m 15s	remaining: 2.21s
# 9850:	learn: 1.1284208	test: 1.2238944	best: 1.2238944 (9850)	total: 2m 15s	remaining: 2.19s
# 9851:	total: 2m 15s	remaining: 2.17s
# 9852:	total: 2m 15s	remaining: 2.16s
# 9853:	total: 2m 15s	remaining: 2.15s
# 9854:	total: 2m 15s	remaining: 2.13s
# 9855:	learn: 1.1283684	test: 1.2238774	best: 1.2238774 (9855)	total: 2m 15s	remaining: 2.12s
# 9856:	total: 2m 15s	remaining: 2.1s
# 9857:	total: 2m 15s	remaining: 2.09s
# 9858:	total: 2m 15s	remaining: 2.07s
# 9859:	total: 2m 15s	remaining: 2.06s
# 9860:	learn: 1.1283172	test: 1.2238771	best: 1.2238701 (9858)	total: 2m 15s	remaining: 2.04s
# 9861:	total: 2m 15s	remaining: 2.03s
# 9862:	total: 2m 15s	remaining: 2.01s
# 9863:	total: 2m 15s	remaining: 2s
# 9864:	total: 2m 15s	remaining: 1.99s
# 9865:	learn: 1.1282753	test: 1.2238782	best: 1.2238701 (9858)	total: 2m 15s	remaining: 1.97s
# 9866:	total: 2m 15s	remaining: 1.96s
# 9867:	total: 2m 15s	remaining: 1.94s
# 9868:	total: 2m 15s	remaining: 1.93s
# 9869:	total: 2m 15s	remaining: 1.91s
# 9870:	learn: 1.1282330	test: 1.2238790	best: 1.2238701 (9858)	total: 2m 15s	remaining: 1.9s
# 9871:	total: 2m 15s	remaining: 1.9s
# 9872:	total: 2m 15s	remaining: 1.87s
# 9873:	total: 2m 15s	remaining: 1.87s
# 9874:	total: 2m 15s	remaining: 1.84s
# 9875:	learn: 1.1281735	test: 1.2238468	best: 1.2238468 (9875)	total: 2m 15s	remaining: 1.82s
# 9876:	total: 2m 15s	remaining: 1.81s
# 9877:	total: 2m 15s	remaining: 1.79s
# 9878:	total: 2m 15s	remaining: 1.78s
# 9879:	total: 2m 15s	remaining: 1.76s
# 9880:	learn: 1.1281293	test: 1.2238479	best: 1.2238468 (9875)	total: 2m 15s	remaining: 1.75s
# 9881:	total: 2m 15s	remaining: 1.74s
# 9882:	total: 2m 15s	remaining: 1.72s
# 9883:	total: 2m 15s	remaining: 1.71s
# 9884:	total: 2m 15s	remaining: 1.69s
# 9885:	learn: 1.1280713	test: 1.2238372	best: 1.2238372 (9883)	total: 2m 15s	remaining: 1.68s
# 9886:	total: 2m 15s	remaining: 1.66s
# 9887:	total: 2m 15s	remaining: 1.65s
# 9888:	total: 2m 15s	remaining: 1.63s
# 9889:	total: 2m 15s	remaining: 1.62s
# 9890:	learn: 1.1280179	test: 1.2238298	best: 1.2238298 (9890)	total: 2m 16s	remaining: 1.6s
# 9891:	total: 2m 16s	remaining: 1.59s
# 9892:	total: 2m 16s	remaining: 1.57s
# 9893:	total: 2m 16s	remaining: 1.56s
# 9894:	total: 2m 16s	remaining: 1.54s
# 9895:	learn: 1.1279669	test: 1.2238351	best: 1.2238298 (9890)	total: 2m 16s	remaining: 1.53s
# 9896:	total: 2m 16s	remaining: 1.51s
# 9897:	total: 2m 16s	remaining: 1.5s
# 9898:	total: 2m 16s	remaining: 1.48s
# 9899:	total: 2m 16s	remaining: 1.47s
# 9900:	learn: 1.1279127	test: 1.2238361	best: 1.2238298 (9890)	total: 2m 16s	remaining: 1.46s
# 9901:	total: 2m 16s	remaining: 1.44s
# 9902:	total: 2m 16s	remaining: 1.43s
# 9903:	total: 2m 16s	remaining: 1.41s
# 9904:	total: 2m 16s	remaining: 1.4s
# 9905:	learn: 1.1278705	test: 1.2238235	best: 1.2238235 (9905)	total: 2m 16s	remaining: 1.38s
# 9906:	total: 2m 16s	remaining: 1.37s
# 9907:	total: 2m 16s	remaining: 1.35s
# 9908:	total: 2m 16s	remaining: 1.34s
# 9909:	total: 2m 16s	remaining: 1.32s
# 9910:	learn: 1.1278265	test: 1.2238175	best: 1.2238164 (9909)	total: 2m 16s	remaining: 1.31s
# 9911:	total: 2m 16s	remaining: 1.29s
# 9912:	total: 2m 16s	remaining: 1.28s
# 9913:	total: 2m 16s	remaining: 1.26s
# 9914:	total: 2m 16s	remaining: 1.25s
# 9915:	learn: 1.1277819	test: 1.2238093	best: 1.2238093 (9915)	total: 2m 16s	remaining: 1.23s
# 9916:	total: 2m 16s	remaining: 1.22s
# 9917:	total: 2m 16s	remaining: 1.21s
# 9918:	total: 2m 16s	remaining: 1.19s
# 9919:	total: 2m 16s	remaining: 1.18s
# 9920:	learn: 1.1277341	test: 1.2237999	best: 1.2237999 (9920)	total: 2m 16s	remaining: 1.16s
# 9921:	total: 2m 16s	remaining: 1.15s
# 9922:	total: 2m 16s	remaining: 1.13s
# 9923:	total: 2m 16s	remaining: 1.12s
# 9924:	total: 2m 16s	remaining: 1.1s
# 9925:	learn: 1.1276694	test: 1.2237994	best: 1.2237994 (9925)	total: 2m 16s	remaining: 1.09s
# 9926:	total: 2m 16s	remaining: 1.07s
# 9927:	total: 2m 16s	remaining: 1.06s
# 9928:	total: 2m 16s	remaining: 1.04s
# 9929:	total: 2m 16s	remaining: 1.03s
# 9930:	learn: 1.1276142	test: 1.2237952	best: 1.2237934 (9926)	total: 2m 16s	remaining: 1.01s
# 9931:	total: 2m 16s	remaining: 1000ms
# 9932:	total: 2m 16s	remaining: 985ms
# 9933:	total: 2m 16s	remaining: 970ms
# 9934:	total: 2m 16s	remaining: 956ms
# 9935:	learn: 1.1275746	test: 1.2237990	best: 1.2237923 (9932)	total: 2m 16s	remaining: 941ms
# 9936:	total: 2m 16s	remaining: 926ms
# 9937:	total: 2m 16s	remaining: 912ms
# 9938:	total: 2m 16s	remaining: 897ms
# 9939:	total: 2m 16s	remaining: 882ms
# 9940:	learn: 1.1275209	test: 1.2237761	best: 1.2237761 (9940)	total: 2m 16s	remaining: 867ms
# 9941:	total: 2m 16s	remaining: 853ms
# 9942:	total: 2m 16s	remaining: 838ms
# 9943:	total: 2m 16s	remaining: 823ms
# 9944:	total: 2m 16s	remaining: 809ms
# 9945:	learn: 1.1274732	test: 1.2237801	best: 1.2237734 (9942)	total: 2m 16s	remaining: 794ms
# 9946:	total: 2m 16s	remaining: 779ms
# 9947:	total: 2m 16s	remaining: 764ms
# 9948:	total: 2m 16s	remaining: 750ms
# 9949:	total: 2m 16s	remaining: 735ms
# 9950:	learn: 1.1274284	test: 1.2237868	best: 1.2237734 (9942)	total: 2m 16s	remaining: 720ms
# 9951:	total: 2m 16s	remaining: 706ms
# 9952:	total: 2m 16s	remaining: 691ms
# 9953:	total: 2m 16s	remaining: 676ms
# 9954:	total: 2m 16s	remaining: 662ms
# 9955:	learn: 1.1273804	test: 1.2237921	best: 1.2237734 (9942)	total: 2m 16s	remaining: 647ms
# 9956:	total: 2m 16s	remaining: 632ms
# 9957:	total: 2m 16s	remaining: 617ms
# 9958:	total: 2m 16s	remaining: 603ms
# 9959:	total: 2m 16s	remaining: 588ms
# 9960:	learn: 1.1273303	test: 1.2237860	best: 1.2237734 (9942)	total: 2m 17s	remaining: 573ms
# 9961:	total: 2m 17s	remaining: 559ms
# 9962:	total: 2m 17s	remaining: 544ms
# 9963:	total: 2m 17s	remaining: 529ms
# 9964:	total: 2m 17s	remaining: 515ms
# 9965:	learn: 1.1272842	test: 1.2237783	best: 1.2237734 (9942)	total: 2m 17s	remaining: 500ms
# 9966:	total: 2m 17s	remaining: 485ms
# 9967:	total: 2m 17s	remaining: 470ms
# 9968:	total: 2m 17s	remaining: 456ms
# 9969:	total: 2m 17s	remaining: 441ms
# 9970:	learn: 1.1272360	test: 1.2237828	best: 1.2237734 (9942)	total: 2m 17s	remaining: 426ms
# 9971:	total: 2m 17s	remaining: 412ms
# 9972:	total: 2m 17s	remaining: 397ms
# 9973:	total: 2m 17s	remaining: 382ms
# 9974:	total: 2m 17s	remaining: 368ms
# 9975:	learn: 1.1271862	test: 1.2237838	best: 1.2237734 (9942)	total: 2m 17s	remaining: 353ms
# 9976:	total: 2m 17s	remaining: 338ms
# 9977:	total: 2m 17s	remaining: 323ms
# 9978:	total: 2m 17s	remaining: 309ms
# 9979:	total: 2m 17s	remaining: 294ms
# 9980:	learn: 1.1271406	test: 1.2237907	best: 1.2237734 (9942)	total: 2m 17s	remaining: 279ms
# 9981:	total: 2m 17s	remaining: 265ms
# 9982:	total: 2m 17s	remaining: 250ms
# 9983:	total: 2m 17s	remaining: 235ms
# 9984:	total: 2m 17s	remaining: 221ms
# 9985:	learn: 1.1271033	test: 1.2237927	best: 1.2237734 (9942)	total: 2m 17s	remaining: 206ms
# 9986:	total: 2m 17s	remaining: 191ms
# 9987:	total: 2m 17s	remaining: 176ms
# 9988:	total: 2m 17s	remaining: 162ms
# 9989:	total: 2m 17s	remaining: 147ms
# 9990:	learn: 1.1270548	test: 1.2237934	best: 1.2237734 (9942)	total: 2m 17s	remaining: 132ms
# 9991:	total: 2m 17s	remaining: 118ms
# 9992:	total: 2m 17s	remaining: 103ms
# 9993:	total: 2m 17s	remaining: 88.2ms
# 9994:	total: 2m 17s	remaining: 73.5ms
# 9995:	learn: 1.1270052	test: 1.2237849	best: 1.2237734 (9942)	total: 2m 17s	remaining: 58.8ms
# 9996:	total: 2m 17s	remaining: 44.1ms
# 9997:	total: 2m 17s	remaining: 29.4ms
# 9998:	total: 2m 17s	remaining: 14.7ms
# 9999:	learn: 1.1269685	test: 1.2237884	best: 1.2237734 (9942)	total: 2m 17s	remaining: 0us
# bestTest = 1.223773438
# bestIteration = 9942
# Shrink model to first 9943 iterations.
# 1.2253151787696839 0.004990338408543602

# %%
pd.DataFrame(
    zip(models_list[0].feature_importances_, X_train.columns, strict=False)
).sort_values(by=0, ascending=False).head(10)
# Out:
#              0                                  1
# 25    9.825129               day_of_month_nunique
# 31    5.079247    time_between_last_and_end_hours
# 34    4.745681                        month_9_sum
# 30    3.728718     time_between_last_and_end_days
# 27    2.946809  time_between_first_and_last_hours
# 1203  2.112257       fraction_mcc_code_count_6012
# 1209  2.082524       fraction_mcc_code_count_6536
# 534   1.775764                   is_wknd_1_median
# 5     1.583212                      amount_median
# 541   1.523834             fraction_month_count_9

# %%
y_pred = np.zeros(X_test.shape[0])

for model in models_list:
    y_pred += model.predict(X_test)

y_pred /= len(models_list)

# %%
submission["target"] = y_pred

submission.to_csv("submissions/regressor_test.csv", index=False)
